# %% [markdown]
# # Scraping Maryland Business Licenses with Selenium
#
# Maryland has a [great portal](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp) for searching business licenses, but the only problem is you have to check a box in order to get in.
#
# 1. Try to visit [the public search page](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp)
# 2. Get redirected to a "I agree to this" page. Click that you've read the disclaimer, click Enter the Site.
# 3. Click "Search License Records" down at the bottom of the page
# 4. You're now on the search page! From the "Jurisdiction" dropdown, select "Statewide"
# 5. In the "Trade Name" field, type "Vap%" to try to find vape shops
# 6. Click "Next" in the bottom right-hand corner to go to the next page
# 7. Click "Click for detail" to see the details for a specific business license.
#
# That's a lot of stuff! **Let's get to work.**

# %% [markdown]
# ## Preparation
#
# ### When you search for a business license, what URL should Selenium try to visit first?

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver = webdriver.Chrome()

# %%
# url = "https://jportal.mdcourts.gov/license/index_disclaimer.jsp"

# %% [markdown]
# **It isn't going to work, though! It's going to redirect to that intro page.** You can use *Incognito mode* to go back through the "Check the box, etc" series of pages.
#
# ### How will you identify the checkbox to check it?
#
# Selenium can find elements by:
#
# - name
# - Class
# - ID
# - CSS selector (**ASK ME WHAT THIS IS** if you don't know)
# - XPath (**ASK ME WHAT THIS IS** because you definitely don't know)
# - Link text
# - Partial link text
#
# So in other words, what's unique about this element?
#
# - *TIP: I have a secret awesome way to do this, but you have to ask.*

# %%
# checkbox = driver.find_element_by_xpath('//*[@id="checkbox"]')
# checkbox.click()

# %% [markdown]
# ### How will you identify the button to select it, or the form to submit it?
#
# Selenium can submit forms by either
#
# - Selecting the form and using `.submit()`, or
# - Selecting the button and using `.click()`
#
# You only need to be able to get **one, not both.**

# %%
# button = driver.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]')
# button.click()

# %% [markdown]
# ### Once you're on the next page, how will you click the "SEARCH LICENSE RECORDS" link or follow its URL?

# %%
# link = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[6]/td[2]/a[2]')
# link.click()

# %% [markdown]
# ### Now you're on the form page. How do you pick "Statewide" for the jurisdiction dropdown?

# %%
# dropdown = driver.find_element_by_xpath('//*[@id="slcJurisdiction"]')
# select = Select(dropdown)
# select.select_by_visible_text("Statewide")

# %% [markdown]
# ### How do you type "vap%" into the Trade Name field?

# %%
# tradeName = driver.find_element_by_xpath('//*[@id="txtTradeName"]')
# tradeName.send_keys("vap%")

# %% [markdown]
# ### How do you click the submit button or submit the form?

# %%
# searchButton = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/form/table/tbody/tr[14]/td/input[1]')
# searchButton.click()

# %% [markdown]
# ### How can you find and click the 'Next' button on the search results page?

# %%
# nextButton = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr')
# nextButton.click()

# %% [markdown]
# # Okay, let's scrape!
#
# ### Use Selenium to search for vape shops statewide, and then click through until it reaches the last page.
#
# Don't scrape yet!

# %%
# Pulls in ability to control a web browser using Selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
# Tell Selenium to open browser 
driver = webdriver.Chrome() 
# In order to get Selenium to visit a page, use driver.get()
driver.get('https://jportal.mdcourts.gov/license/index_disclaimer.jsp')
checkbox = driver.find_element_by_xpath('//*[@id="checkbox"]')
checkbox.click()
button = driver.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]')
button.click()
link = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[6]/td[2]/a[2]')
link.click()

dropdown = driver.find_element_by_xpath('//*[@id="slcJurisdiction"]')
select = Select(dropdown)
select.select_by_visible_text("Statewide")
tradeName = driver.find_element_by_xpath('//*[@id="txtTradeName"]')
tradeName.send_keys("vap%")

searchButton = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/form/table/tbody/tr[14]/td/input[1]')
searchButton.click()

nextButton = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr')
nextButton.click()

# %% [markdown]
# ### Use Selenium to scrape the first page of search results for vape shops statewide (well, we'll try).
#
# - *TIP: You can find elements/text using Selenium, or use BeautifulSoup with `doc = BeautifulSoup(driver.page_source)`*
#
# I've included some BeautifulSoup code that might be helpful. If you use it, **ask me how I made it.** It's important.

# %%
# IF YOU ARE USING BEAUTIFULSOUP, HERE IS SOME SAMPLE CODE
# IF YOU USE THIS CODE, ASK ME HOW I MADE IT. IT'S IMPORTANT.
from bs4 import BeautifulSoup
doc = BeautifulSoup(driver.page_source, "html.parser")
business_headers = doc.find_all('tr',class_='searchfieldtitle')
business_headers
# Out:
# [<tr class="searchfieldtitle">
#  <td class="searchlistnumber">1.</td>
#  <td class="searchlistitem"><span class="copybold">VAPE IT STORE I</span></td>
#  <td><a href="pbLicenseDetail.jsp?owi=KdVIRFZaRSk%3D"><img alt="Click for Detail of VAPE IT STORE I" src="images/link_click-detail.gif"/></a></td>
#  </tr>, <tr class="searchfieldtitle">
#  <td class="searchlistnumber">2.</td>
#  <td class="searchlistitem"><span class="copybold">VAPE IT STORE II</span></td>
#  <td><a href="pbLicenseDetail.jsp?owi=cwUAHU2nGzk%3D"><img alt="Click for Detail of VAPE IT STORE II" src="images/link_click-detail.gif"/></a></td>
#  </tr>, <tr class="searchfieldtitle">
#  <td class="searchlistnumber">3.</td>
#  <td class="searchlistitem"><span class="copybold">VAPEPAD THE</span></td>
#  <td><a href="pbLicenseDetail.jsp?owi=tqd4cn5Q%2BEw%3D"><img alt="Click for Detail of VAPEPAD THE" src="images/link_click-detail.gif"/></a></td>
#  </tr>, <tr class="searchfieldtitle">
#  <td class="searchlistnumber">4.</td>
#  <td class="searchlistitem"><span class="copybold">VAPE FROG</span></td>
#  <td><a href="pbLicenseDetail.jsp?owi=sg9UTFEk1k4%3D"><img alt="Click for Detail of VAPE FROG" src="images/link_click-detail.gif"/></a></td>
#  </tr>, <tr class="searchfieldtitle">
#  <td class="searchlistnumber">5.</td>
#  <td class="searchlistitem"><span class="copybold">VAPE FROG</span></td>
#  <td>Pending <span class="searchlistred">*</span></td>
#  </tr>]

# %%
# You'll probably need to find specific tds inside
# of the rows instead of looking at the whole thing.
for header in business_headers:
    rows = header.find_next_siblings('tr')
    print(header.text.strip())
    print(rows[0].text.strip())
    print(rows[1].text.strip())
    print(rows[2].text.strip())
    print(rows[3].text.strip())
    print("___")
# Out:
# 1.
# VAPE IT STORE I
# AMIN NARGIS
# Lic. Status: Issued
# 1724 N SALISBURY BLVD UNIT 2
# License: 22173807
# SALISBURY, MD 21801
# Issued Date: 4/27/2017
# Wicomico County
# ___
# 2.
# VAPE IT STORE II
# AMIN NARGIS
# Lic. Status: Issued
# 1015 S SALISBURY BLVD
# License: 22173808
# SALISBURY, MD 21801
# Issued Date: 4/27/2017
# Wicomico County
# ___
# 3.
# VAPEPAD THE
# ANJ DISTRIBUTIONS LLC
# Lic. Status: Issued
# 2299 JOHNS HOPKINS ROAD
# License: 02104436
# GAMBRILLS, MD 21054
# Issued Date: 4/05/2017
# Anne Arundel County
# ___
# 4.
# VAPE FROG
# COX TRADING COMPANY L L C
# Lic. Status: Issued
# 110 S. PINEY RD
# License: 17165957
# CHESTER, MD 21619
# Issued Date: 5/31/2017
# Queen Anne's County
# ___
# 5.
# VAPE FROG
# Pending *
# COX TRADING LLC
# Lic. Status: Pending
# 346 RITCHIE HIGHWAY
# SEVERNA PARK, MD 21146
# Anne Arundel County
# ___

# %%
list_companies = []
for header in business_headers:
    company = {}
    rows = header.find_next_siblings('tr')
    company['trade_name'] = header.find_all('td')[1].text.strip()
    company['company_name'] = rows[0].find_all('td')[1].text.strip()
    company['city_name'] = rows[2].find_all('td')[1].text.strip()
    company['address'] = rows[1].find_all('td')[1].text.strip()
    company['county'] = rows[3].find_all('td')[1].text.strip()
    company_url = header.find_all('td')[2].find('a', href=True)
    if company_url:
        company['detail_link'] = 'https://jportal.mdcourts.gov/license/'+company_url['href']
    else:
        company['detail_link'] = ''
    license_number = rows[1].find_all('td')[2].find('span')
    if license_number is not None:
        company['license_status'] = rows[0].find_all('td')[2].find('span').next_sibling.strip()
        company['license_number'] = rows[1].find_all('td')[2].find('span').next_sibling.strip()
        company['issue_date'] = rows[2].find_all('td')[2].find('span').next_sibling.strip()
    else:
        company['license_status'] = rows[0].find_all('td')[2].find('span').next_sibling.strip()
        company['license_number'] = ""
        company['issue_date'] = ""
    list_companies.append(company)
list_companies
# Out:
# [{'address': '1724 N SALISBURY BLVD UNIT 2',
#   'city_name': 'SALISBURY, MD 21801',
#   'company_name': 'AMIN NARGIS',
#   'county': 'Wicomico County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=KdVIRFZaRSk%3D',
#   'issue_date': '4/27/2017',
#   'license_number': '22173807',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE IT STORE I'},
#  {'address': '1015 S SALISBURY BLVD',
#   'city_name': 'SALISBURY, MD 21801',
#   'company_name': 'AMIN NARGIS',
#   'county': 'Wicomico County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=cwUAHU2nGzk%3D',
#   'issue_date': '4/27/2017',
#   'license_number': '22173808',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE IT STORE II'},
#  {'address': '2299 JOHNS HOPKINS ROAD',
#   'city_name': 'GAMBRILLS, MD 21054',
#   'company_name': 'ANJ DISTRIBUTIONS LLC',
#   'county': 'Anne Arundel County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=tqd4cn5Q%2BEw%3D',
#   'issue_date': '4/05/2017',
#   'license_number': '02104436',
#   'license_status': 'Issued',
#   'trade_name': 'VAPEPAD THE'},
#  {'address': '110 S. PINEY RD',
#   'city_name': 'CHESTER, MD 21619',
#   'company_name': 'COX TRADING COMPANY L L C',
#   'county': "Queen Anne's County",
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=sg9UTFEk1k4%3D',
#   'issue_date': '5/31/2017',
#   'license_number': '17165957',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE FROG'},
#  {'address': '346 RITCHIE HIGHWAY',
#   'city_name': 'SEVERNA PARK, MD 21146',
#   'company_name': 'COX TRADING LLC',
#   'county': 'Anne Arundel County',
#   'detail_link': '',
#   'issue_date': '',
#   'license_number': '',
#   'license_status': 'Pending',
#   'trade_name': 'VAPE FROG'}]

# %% [markdown]
# ### Save these into `vape-results.csv`

# %%
import pandas as pd
df = pd.DataFrame(list_companies)
df.to_csv('vape_results.csv',index=False)

# %% [markdown]
# ### Open `vape-results.csv` to make sure there aren't any extra weird columns

# %%
df = pd.read_csv('vape_results.csv')
df
# Out:
#                         address               city_name  \
# 0  1724 N SALISBURY BLVD UNIT 2     SALISBURY, MD 21801
# 1         1015 S SALISBURY BLVD     SALISBURY, MD 21801
# 2       2299 JOHNS HOPKINS ROAD     GAMBRILLS, MD 21054
# 3               110 S. PINEY RD       CHESTER, MD 21619
# 4           346 RITCHIE HIGHWAY  SEVERNA PARK, MD 21146
#
#                 company_name               county  \
# 0                AMIN NARGIS      Wicomico County
# 1                AMIN NARGIS      Wicomico County
# 2      ANJ DISTRIBUTIONS LLC  Anne Arundel County
# 3  COX TRADING COMPANY L L C  Queen Anne's County
# 4            COX TRADING LLC  Anne Arundel County
#
#                                          detail_link issue_date  \
# 0  https://jportal.mdcourts.gov/license/pbLicense...  4/27/2017
# 1  https://jportal.mdcourts.gov/license/pbLicense...  4/27/2017
# 2  https://jportal.mdcourts.gov/license/pbLicense...  4/05/2017
# 3  https://jportal.mdcourts.gov/license/pbLicense...  5/31/2017
# 4                                                NaN        NaN
#
#    license_number license_status        trade_name
# 0      22173807.0         Issued   VAPE IT STORE I
# 1      22173808.0         Issued  VAPE IT STORE II
# 2       2104436.0         Issued       VAPEPAD THE
# 3      17165957.0         Issued         VAPE FROG
# 4             NaN        Pending         VAPE FROG

# %% [markdown]
# ## Use Selenium to scrape ALL pages of results, save the results into `vape-results-all.csv`.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import pandas as pd
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome()
url = "https://jportal.mdcourts.gov/license/index_disclaimer.jsp"
driver.get(url)
checkbox = driver.find_element_by_xpath('//*[@id="checkbox"]')
checkbox.click()
button = driver.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]')
button.click()
link = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[6]/td[2]/a[2]')
link.click()

dropdown = driver.find_element_by_xpath('//*[@id="slcJurisdiction"]')
select = Select(dropdown)
select.select_by_visible_text("Statewide")
tradeName = driver.find_element_by_xpath('//*[@id="txtTradeName"]')
tradeName.send_keys("vap%")
searchButton = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/form/table/tbody/tr[14]/td/input[1]')
searchButton.click()

# %%
def scrape_this_page():
    doc = BeautifulSoup(driver.page_source, "html.parser")
    business_headers = doc.find_all('tr',class_='searchfieldtitle')
    this_list = []
    
    for header in business_headers:
        company = {}
        rows = header.find_next_siblings('tr')
        company['trade_name'] = header.find_all('td')[1].text.strip()
        company['company_name'] = rows[0].find_all('td')[1].text.strip()
        company['city_name'] = rows[2].find_all('td')[1].text.strip()
        company['address'] = rows[1].find_all('td')[1].text.strip()
        company['county'] = rows[3].find_all('td')[1].text.strip()
        company_url = header.find_all('td')[2].find('a', href=True)
        
        if company_url:
            company['detail_link'] = 'https://jportal.mdcourts.gov/license/'+company_url['href']
        else:
            company['detail_link'] = ''
            
        license_number = rows[1].find_all('td')[2].find('span')
        
        if license_number is not None:
            company['license_status'] = rows[0].find_all('td')[2].find('span').next_sibling.strip()
            company['license_number'] = rows[1].find_all('td')[2].find('span').next_sibling.strip()
            company['issue_date'] = rows[2].find_all('td')[2].find('span').next_sibling.strip()
        else:
            company['license_status'] = rows[0].find_all('td')[2].find('span').next_sibling.strip()
            company['license_number'] = ""
            company['issue_date'] = ""
            
        this_list.append(company)
        
    return this_list

# %%
company_list = []

while True:
    try:
        this_list = scrape_this_page()
        company_list += this_list
        nextButton = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr')
        nextButton.click()
    except:
        break

# %%
company_list
# Out:
# [{'address': '1724 N SALISBURY BLVD UNIT 2',
#   'city_name': 'SALISBURY, MD 21801',
#   'company_name': 'AMIN NARGIS',
#   'county': 'Wicomico County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=%2BExmxmrSeEE%3D',
#   'issue_date': '4/27/2017',
#   'license_number': '22173807',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE IT STORE I'},
#  {'address': '1015 S SALISBURY BLVD',
#   'city_name': 'SALISBURY, MD 21801',
#   'company_name': 'AMIN NARGIS',
#   'county': 'Wicomico County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=AOTGUn5%2FFjc%3D',
#   'issue_date': '4/27/2017',
#   'license_number': '22173808',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE IT STORE II'},
#  {'address': '2299 JOHNS HOPKINS ROAD',
#   'city_name': 'GAMBRILLS, MD 21054',
#   'company_name': 'ANJ DISTRIBUTIONS LLC',
#   'county': 'Anne Arundel County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=OQTtBF%2F1Lf8%3D',
#   'issue_date': '4/05/2017',
#   'license_number': '02104436',
#   'license_status': 'Issued',
#   'trade_name': 'VAPEPAD THE'},
#  {'address': '110 S. PINEY RD',
#   'city_name': 'CHESTER, MD 21619',
#   'company_name': 'COX TRADING COMPANY L L C',
#   'county': "Queen Anne's County",
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=WWYCd4s7GX8%3D',
#   'issue_date': '5/31/2017',
#   'license_number': '17165957',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE FROG'},
#  {'address': '346 RITCHIE HIGHWAY',
#   'city_name': 'SEVERNA PARK, MD 21146',
#   'company_name': 'COX TRADING LLC',
#   'county': 'Anne Arundel County',
#   'detail_link': '',
#   'issue_date': '',
#   'license_number': '',
#   'license_status': 'Pending',
#   'trade_name': 'VAPE FROG'},
#  {'address': '185 MITCHELLS CHANCE RD',
#   'city_name': 'EDGEWATER, MD 21037',
#   'company_name': 'DISBROW II EMERSON HARRINGTON',
#   'county': 'Anne Arundel County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=DeJOzAXawak%3D',
#   'issue_date': '4/13/2017',
#   'license_number': '02102408',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE LOFT (THE)'},
#  {'address': '7104 MINSTREL UNIT #7',
#   'city_name': 'COLUMBIA, MD 21045',
#   'company_name': 'DISCOUNT TOBACCO ESSEX LLC',
#   'county': 'Howard County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=N1wmBDiqzo4%3D',
#   'issue_date': '5/19/2017',
#   'license_number': '13141786',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE N CIGAR'},
#  {'address': '330 ONE FORTY VILLAGE ROAD',
#   'city_name': 'WESTMINSTER, MD 21157',
#   'company_name': 'FAIRGROUND VILLAGE LLC',
#   'county': 'Carroll County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=luQiOEK0apQ%3D',
#   'issue_date': '4/21/2017',
#   'license_number': '06126253',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE DOJO'},
#  {'address': '29890 THREE NOTCH ROAD',
#   'city_name': 'CHARLOTTE HALL, MD 20622',
#   'company_name': 'GRIMM JENNIFER',
#   'county': "St. Mary's County",
#   'detail_link': '',
#   'issue_date': '',
#   'license_number': '',
#   'license_status': 'Pending',
#   'trade_name': 'VAPE HAVEN'},
#  {'address': '356 ROMANCOKE ROAD',
#   'city_name': 'STEVENSVILLE, MD 21666',
#   'company_name': 'HUTCH VAPES LLC',
#   'county': "Queen Anne's County",
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=NgVXnuWD3oM%3D',
#   'issue_date': '4/13/2017',
#   'license_number': '17166688',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE BIRD'},
#  {'address': '110 S PINEY ROAD  STE 106',
#   'city_name': 'CHESTER, MD 21619',
#   'company_name': 'HUTCHINS COX LLP',
#   'county': "Queen Anne's County",
#   'detail_link': '',
#   'issue_date': '',
#   'license_number': '',
#   'license_status': 'Pending',
#   'trade_name': 'VAPE FROG'},
#  {'address': '28943 THREE NOTCH ROAD',
#   'city_name': 'MECHANICSVILLE, MD 20659',
#   'company_name': 'JAMESON WILLIAM',
#   'county': "St. Mary's County",
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=jAu5xdtG%2F7Q%3D',
#   'issue_date': '5/17/2017',
#   'license_number': '18167503',
#   'license_status': 'Issued',
#   'trade_name': 'VAPORS LOUNGE'},
#  {'address': '6843 CRAIN HIGHWAY',
#   'city_name': 'LA PLATA, MD 20646',
#   'company_name': 'JAMESON WILLIAM E',
#   'county': 'Charles County',
#   'detail_link': '',
#   'issue_date': '',
#   'license_number': '',
#   'license_status': 'Pending',
#   'trade_name': 'VAPORS LOUNGE'},
#  {'address': '6321 OLD BRANCH AVE',
#   'city_name': 'CAMP SPRINGS, MD 20748',
#   'company_name': 'JEFFERS MICHAEL',
#   'county': "St. Mary's County",
#   'detail_link': '',
#   'issue_date': '',
#   'license_number': '',
#   'license_status': 'Pending',
#   'trade_name': 'VAPIST MD'},
#  {'address': '6321 OLD BRANCH AVE',
#   'city_name': 'CAMP SPRINGS, MD 20748',
#   'company_name': 'JEFFERS MICHAEL W',
#   'county': "Prince George's County",
#   'detail_link': '',
#   'issue_date': '',
#   'license_number': '',
#   'license_status': 'Pending',
#   'trade_name': 'VAPIST MD LLC'},
#  {'address': '7954 B AND A BLVD',
#   'city_name': 'GLEN BURNIE, MD 21060',
#   'company_name': 'SHIN JENNY Y',
#   'county': 'Anne Arundel County',
#   'detail_link': '',
#   'issue_date': '',
#   'license_number': '',
#   'license_status': 'Pending',
#   'trade_name': 'VAPERTETMD'},
#  {'address': '6325 WASHINGTON BLVD',
#   'city_name': 'ELKRIDGE, MD 21075',
#   'company_name': 'SHIN JENNY YOUNG',
#   'county': 'Howard County',
#   'detail_link': '',
#   'issue_date': '',
#   'license_number': '',
#   'license_status': 'Pending',
#   'trade_name': 'VAPERTEKMD'},
#  {'address': '3203 NORTH POINT RD',
#   'city_name': 'BALTIMORE, MD 21222',
#   'company_name': 'TAYLOR TRAVIS',
#   'county': 'Baltimore County',
#   'detail_link': '',
#   'issue_date': '',
#   'license_number': '',
#   'license_status': 'Pending',
#   'trade_name': 'VAPORIOT'},
#  {'address': '519 LINDEN AVENUE UNIT 6',
#   'city_name': 'POCOMOKE CITY, MD 21851',
#   'company_name': 'TRUE ENTERPRISE INC',
#   'county': 'Worcester County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=IUmWdexC%2Bqc%3D',
#   'issue_date': '5/05/2017',
#   'license_number': '23178140',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE PLUS'},
#  {'address': '16521 S FREDERICK AVE',
#   'city_name': 'GAITHERSBURG, MD 20877',
#   'company_name': 'VAPE  SOCIAL  LLC',
#   'county': 'Montgomery County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=1h03do0Jo7g%3D',
#   'issue_date': '4/18/2017',
#   'license_number': '15155429',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE  SOCIAL'},
#  {'address': '2070 CRAIN HIGHWAY  UNIT F',
#   'city_name': 'WALDORF, MD 20601',
#   'company_name': 'VAPE JUNGLE LLC',
#   'county': 'Charles County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ViStcVP4%2Bos%3D',
#   'issue_date': '3/31/2017',
#   'license_number': '08131285',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE JUNGLE'},
#  {'address': '4130 E JOPPA RD UNIT 109',
#   'city_name': 'NOTTINGHAM, MD 21236',
#   'company_name': 'VAPE TIME LLC',
#   'county': 'Baltimore County',
#   'detail_link': '',
#   'issue_date': '',
#   'license_number': '',
#   'license_status': 'Pending',
#   'trade_name': 'VAPE TIME'},
#  {'address': '11110 MALL CIRCLE',
#   'city_name': 'WALDORF, MD 20603',
#   'company_name': 'VAPEBAR EXPRESS LLC',
#   'county': 'Charles County',
#   'detail_link': '',
#   'issue_date': '',
#   'license_number': '',
#   'license_status': 'Pending',
#   'trade_name': 'VAPEBAR EXPESS'},
#  {'address': '3524 CRAIN HWY',
#   'city_name': 'BOWIE, MD 20716',
#   'company_name': 'VAPOR 99 LLC',
#   'county': "Prince George's County",
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=sbbV6kKB0P0%3D',
#   'issue_date': '5/03/2017',
#   'license_number': '16165362',
#   'license_status': 'Issued',
#   'trade_name': 'VAPOR 99'},
#  {'address': '8117 OCEAN GATEWAY UNIT #4',
#   'city_name': 'EASTON, MD 21601',
#   'company_name': 'VAPOR ALLEY LLC',
#   'county': 'Talbot County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=OUht3UpERzU%3D',
#   'issue_date': '5/10/2017',
#   'license_number': '20170900',
#   'license_status': 'Issued',
#   'trade_name': 'VAPOR ALLEY'},
#  {'address': '11717 OLD NATIONAL PIKE',
#   'city_name': 'NEW MARKET, MD 21774',
#   'company_name': 'VAPOR EMPORIUM MD LLC',
#   'county': 'Frederick County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ceR3b2coshg%3D',
#   'issue_date': '4/14/2017',
#   'license_number': '10135432',
#   'license_status': 'Issued',
#   'trade_name': 'VAPOR EMPORIUM'},
#  {'address': '1913 LANSDOWNE ROAD SUITE E',
#   'city_name': 'BALTIMORE, MD 21227',
#   'company_name': 'VAPOR VILLA CORP',
#   'county': 'Baltimore County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=mOvazVwkJkw%3D',
#   'issue_date': '4/12/2017',
#   'license_number': '03121958',
#   'license_status': 'Issued',
#   'trade_name': 'VAPOR VILLA'},
#  {'address': '730 FREDERICK ROAD',
#   'city_name': 'CATONSVILLE, MD 21228',
#   'company_name': 'VAPOR VILLA CORP',
#   'county': 'Baltimore County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=JnIC%2BVfAxzg%3D',
#   'issue_date': '4/12/2017',
#   'license_number': '03121959',
#   'license_status': 'Issued',
#   'trade_name': 'VAPOR VILLA'},
#  {'address': '138 N BOND STREET',
#   'city_name': 'BEL AIR, MD 21014',
#   'company_name': 'WALKER TRADING CO INC',
#   'county': 'Harford County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=oN7wOqo5kJE%3D',
#   'issue_date': '4/03/2017',
#   'license_number': '12140135',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE DOJO'},
#  {'address': '11600 CROSSROAD CIR  STE E',
#   'city_name': 'BALTIMORE, MD 21220',
#   'company_name': 'WALKER TRADING COMPANY INC',
#   'county': 'Baltimore County',
#   'detail_link': '',
#   'issue_date': '',
#   'license_number': '',
#   'license_status': 'Pending',
#   'trade_name': 'VAPE DOJO'},
#  {'address': '3570 SAINT JOHNS LANE, SUITE 109',
#   'city_name': 'ELLICOTT CITY, MD 21042',
#   'company_name': 'WALKER TRADING COMPANY INC',
#   'county': 'Howard County',
#   'detail_link': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=aYxZ8%2FjmPko%3D',
#   'issue_date': '3/27/2017',
#   'license_number': '13144108',
#   'license_status': 'Issued',
#   'trade_name': 'VAPE DOJO'},
#  {'address': '3315 PLAZA WAY',
#   'city_name': 'WALDORF, MD 20603',
#   'company_name': 'YARKHOUSE EMPIRE INC',
#   'county': 'Charles County',
#   'detail_link': '',
#   'issue_date': '',
#   'license_number': '',
#   'license_status': 'Pending',
#   'trade_name': 'VAPEZ YARDHOUSE'}]

# %%
df = pd.DataFrame(company_list)
df.to_csv('vape_results_all.csv',index=False)

# %%
df.head()
# Out:
#                         address               city_name  \
# 0  1724 N SALISBURY BLVD UNIT 2     SALISBURY, MD 21801
# 1         1015 S SALISBURY BLVD     SALISBURY, MD 21801
# 2       2299 JOHNS HOPKINS ROAD     GAMBRILLS, MD 21054
# 3               110 S. PINEY RD       CHESTER, MD 21619
# 4           346 RITCHIE HIGHWAY  SEVERNA PARK, MD 21146
#
#                 company_name               county  \
# 0                AMIN NARGIS      Wicomico County
# 1                AMIN NARGIS      Wicomico County
# 2      ANJ DISTRIBUTIONS LLC  Anne Arundel County
# 3  COX TRADING COMPANY L L C  Queen Anne's County
# 4            COX TRADING LLC  Anne Arundel County
#
#                                          detail_link issue_date  \
# 0  https://jportal.mdcourts.gov/license/pbLicense...  4/27/2017
# 1  https://jportal.mdcourts.gov/license/pbLicense...  4/27/2017
# 2  https://jportal.mdcourts.gov/license/pbLicense...  4/05/2017
# 3  https://jportal.mdcourts.gov/license/pbLicense...  5/31/2017
# 4
#
#   license_number license_status        trade_name
# 0       22173807         Issued   VAPE IT STORE I
# 1       22173808         Issued  VAPE IT STORE II
# 2       02104436         Issued       VAPEPAD THE
# 3       17165957         Issued         VAPE FROG
# 4                       Pending         VAPE FROG
