# %% [markdown]
# # Corporate Prosecution - Exercise B
#
# #### Summary
#
# Looking at corporate prosecutions over time, and the possible assignment of a compliance officer.
#
# #### Files
#
# - cpr-data.xls, "detailed information about every federal organizational prosecution since 2001, as well as deferred and non-prosecution agreements with organizations since 1990"
#
# #### Data Source(s)
#
# The UVA School of Law publishees a [Corpoate Prosecution Registry](http://lib.law.virginia.edu/Garrett/corporate-prosecution-registry/about.html)
#
# > The goal of this Corporate Prosecutions Registry is to provide comprehensive and up-to-date information on federal organizational prosecutions in the United States, so that we can better understand how corporate prosecutions are brought and resolved. We include detailed information about every federal organizational prosecution since 2001, as well as deferred and non-prosecution agreements with organizations since 1990.
#
# [Corpoate Prosecution Registry](http://lib.law.virginia.edu/Garrett/corporate-prosecution-registry/about.html)
#
# #### Skills
#
# - Working with CSV files
# - Counting and summarizing columns
# - Searching with strings
# - Extracting with strings

# %% [markdown]
# # Read in `cpr-data.csv`

# %%
import pandas as pd 

df = pd.read_csv("cpr-data.csv")
df.head()

# df = pd.read_csv("cpr-data.csv", na_values=["Unknown", "-999", "???"])
# Out:
#    REC_ID                                 COMPANY DISPOSITION_TYPE  \
# 0     138  1st Union Transfer and Telegraph, Inc.             plea
# 1     139                3D Poultry Loading, Inc.             plea
# 2    2529                         3rd & Bell, LLC             plea
# 3     822                          41 Market Inc.             plea
# 4     140                            45,000, Inc.             plea
#
#                          PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM  \
# 0                          Money Laundering                NaN
# 1                               Immigration                NaN
# 2                               Immigration                NaN
# 3  Controlled substances / Drugs / Meth Act                NaN
# 4                             Environmental                NaN
#
#                           USAO        COUNTRY FINANCIAL_INSTITUTION  \
# 0  Virginia - Eastern District  United States                   Yes
# 1  Arkansas - Western District  United States                    No
# 2                      Arizona  United States                    No
# 3  Georgia - Northern District  United States                    No
# 4  Louisiana - Middle District  United States                    No
#
#                                       CASE_NAME        CASE_ID  ...    \
# 0                     USA v. 1st Union Transfer  4:03-cr-00024  ...
# 1                     USA v. 3D Poultry Loading  2:04-cr-20061  ...
# 2  USA v. Danny's Management Services LLC et al  2:13-cr-01143  ...
# 3                         USA v. 41 Market Inc.  4:06-cr-00023  ...
# 4                              USA v. 45000 Inc  3:04-cr-00180  ...
#
#   PRIVACY_WAIVER REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  \
# 0            NaN                                            NaN
# 1            NaN                                            NaN
# 2            NaN                                            NaN
# 3            NaN                                            NaN
# 4            NaN                                            NaN
#
#   REGULATORY_FINE REG_AGENCY STATEMENT_OF_FACTS TOTAL_REGULATORY  \
# 0             NaN        NaN                NaN              NaN
# 1             NaN        NaN                NaN              NaN
# 2             NaN        NaN                NaN              NaN
# 3             NaN        NaN                NaN              NaN
# 4             NaN        NaN                NaN              NaN
#
#    UNRELATED_TERMS  AGMT_YEAR  SOURCE  NOTES
# 0              NaN     2003.0   PACER    NaN
# 1              NaN     2005.0   PACER    NaN
# 2              NaN     2014.0   PACER    NaN
# 3              NaN     2006.0   PACER    NaN
# 4              NaN     2005.0   PACER    NaN
#
# [5 rows x 56 columns]

# %% [markdown]
# ### Check that your dataframe has 3038 rows and 56 columns.

# %%
df.shape
# Out:
# (3038, 56)

# %% [markdown]
# ### List the columns and their data types

# %%
df.dtypes
# Out:
# REC_ID                                                                      int64
# COMPANY                                                                    object
# DISPOSITION_TYPE                                                           object
# PRIMARY_CRIME_CODE                                                         object
# SWISS_BANK_PROGRAM                                                         object
# USAO                                                                       object
# COUNTRY                                                                    object
# FINANCIAL_INSTITUTION                                                      object
# CASE_NAME                                                                  object
# CASE_ID                                                                    object
# DOCKET_NO                                                                  object
# DATE                                                                       object
# JUDGMENT_DATE                                                              object
# PLEA_DATE                                                                  object
# TICKER                                                                     object
# US_PUBLIC_CO                                                               object
# ADDITIONAL_REGULATORY_FINE_OR_PAYMENT                                     float64
# COMMUNITY_SERVICE_OR_OTHER                                                float64
# FINE                                                                      float64
# FORFEITURE_DISGORGEMENT                                                   float64
# PROBATION_LENGTH                                                          float64
# RESTITUTION                                                               float64
# TOTAL_PAYMENT                                                               int64
# ACCEPTS_RESPONSIBILITY                                                     object
# AGREEMENT_REQUIRED_NEW_POSITIONS                                           object
# AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS                             object
# CITATION_AND_DESCRIPTION                                                   object
# CIVIL_JUDGMENT_OR_SETTLEMENT                                               object
# COMPLIANCE_PROGRAM_DESCRIPTION                                             object
# COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT                                   object
# COMPLIANCE_REQUIRED_BY_REGULATORS                                          object
# CRIME_DESC                                                                 object
# DESCRIPTION_OF_PAYMENTS                                                    object
# DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY     object
# DOJ_CAN_UNILATERALLY_TERMINATE                                             object
# FINE_CALCULATION_INCLUDED                                                  object
# FINE_DESCRIPTION                                                           object
# INDEP_MONITOR_REQUIRED                                                     object
# MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE                                 object
# OTHER_AGREEMENT                                                            object
# OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES                                object
# OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED                            object
# PARALLEL_CIVIL_SUIT                                                        object
# PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR                             object
# PRE_AGREEMENT_COMPLIANCE                                                   object
# PRE_AGREEMENT_COMPLIANCE_DESCRIPTION                                       object
# PRIVACY_WAIVER                                                             object
# REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE                            float64
# REGULATORY_FINE                                                           float64
# REG_AGENCY                                                                 object
# STATEMENT_OF_FACTS                                                         object
# TOTAL_REGULATORY                                                          float64
# UNRELATED_TERMS                                                            object
# AGMT_YEAR                                                                 float64
# SOURCE                                                                     object
# NOTES                                                                      object
# dtype: object

# %% [markdown]
# ### What do the following columns mean?
#
# - PRIMARY_CRIME_CODE
# - DISPOSITION_TYPE
# - AGREEMENT_TYPE
# - COUNTRY
# - FINE
# - TOTAL_PAYMENT
# - USAO
# - PROBATION_LENGTH
# - AGREEMENT_REQUIRED_NEW_POSITIONS
# - INDEP_MONITOR_REQUIRED

# %% [markdown]
# PRIMARY_CRIME_CODE - This can include any one of the following: Accounting fraud, bribery, immigration, etc.
#
# DISPOSITION_TYPE - Indicates whether the prosecution was resolved through a type of agreement: a plea ("plea"); non-prosecution agreement ("NP"); or deferred prosecution agreement ("DP"); or whether the prosecution was resolved at trial in a conviction ("trial conviction") or acquittal ("acquittal") or a dismissal before or during trial ("dismissal"); as well as by a declination in which the case was dismissed by the prosecutor ("declination").
#
# AGREEMENT_TYPE - Indicates whether the agreement is a plea ("plea"), non-prosecution agreement ("NP"), or deferred prosecution agreement ("DP")
#
# COUNTRY - Country in which the entity was incorporated.
#
# FINE - Amount of fine in U.S. dollars.
#
# TOTAL_PAYMENT - Sum of all monetary penalties (i.e. fines, restitution, forfeiture, disgorgements, community service, etc.)
#
# USAO - U.S. Attorney's Offices involved in the prosecution. Multiple entries are separated by a "|".

# %% [markdown]
# # Customizing the display in pandas
#
# See how the middle of the table has a `...`? Let's fix that.
#
# ## How do you see the number of columns pandas will display?

# %%
df.columns
# Out:
# Index(['REC_ID', 'COMPANY', 'DISPOSITION_TYPE', 'PRIMARY_CRIME_CODE',
#        'SWISS_BANK_PROGRAM', 'USAO', 'COUNTRY', 'FINANCIAL_INSTITUTION',
#        'CASE_NAME', 'CASE_ID', 'DOCKET_NO', 'DATE', 'JUDGMENT_DATE',
#        'PLEA_DATE', 'TICKER', 'US_PUBLIC_CO',
#        'ADDITIONAL_REGULATORY_FINE_OR_PAYMENT', 'COMMUNITY_SERVICE_OR_OTHER',
#        'FINE', 'FORFEITURE_DISGORGEMENT', 'PROBATION_LENGTH', 'RESTITUTION',
#        'TOTAL_PAYMENT', 'ACCEPTS_RESPONSIBILITY',
#        'AGREEMENT_REQUIRED_NEW_POSITIONS',
#        'AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS',
#        'CITATION_AND_DESCRIPTION', 'CIVIL_JUDGMENT_OR_SETTLEMENT',
#        'COMPLIANCE_PROGRAM_DESCRIPTION',
#        'COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT',
#        'COMPLIANCE_REQUIRED_BY_REGULATORS', 'CRIME_DESC',
#        'DESCRIPTION_OF_PAYMENTS',
#        'DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY',
#        'DOJ_CAN_UNILATERALLY_TERMINATE', 'FINE_CALCULATION_INCLUDED',
#        'FINE_DESCRIPTION', 'INDEP_MONITOR_REQUIRED',
#        'MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE', 'OTHER_AGREEMENT',
#        'OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES',
#        'OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED',
#        'PARALLEL_CIVIL_SUIT', 'PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR',
#        'PRE_AGREEMENT_COMPLIANCE', 'PRE_AGREEMENT_COMPLIANCE_DESCRIPTION',
#        'PRIVACY_WAIVER', 'REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE',
#        'REGULATORY_FINE', 'REG_AGENCY', 'STATEMENT_OF_FACTS',
#        'TOTAL_REGULATORY', 'UNRELATED_TERMS', 'AGMT_YEAR', 'SOURCE', 'NOTES'],
#       dtype='object')

# %%
pd.options.display.max_columns

# ... means it's hiding columns
# Out:
# 20

# %% [markdown]
# ## Set pandas to display 65 columns

# %%
pd.set_option('display.max_columns', 65)
df.head()
# Out:
#    REC_ID                                 COMPANY DISPOSITION_TYPE  \
# 0     138  1st Union Transfer and Telegraph, Inc.             plea
# 1     139                3D Poultry Loading, Inc.             plea
# 2    2529                         3rd & Bell, LLC             plea
# 3     822                          41 Market Inc.             plea
# 4     140                            45,000, Inc.             plea
#
#                          PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM  \
# 0                          Money Laundering                NaN
# 1                               Immigration                NaN
# 2                               Immigration                NaN
# 3  Controlled substances / Drugs / Meth Act                NaN
# 4                             Environmental                NaN
#
#                           USAO        COUNTRY FINANCIAL_INSTITUTION  \
# 0  Virginia - Eastern District  United States                   Yes
# 1  Arkansas - Western District  United States                    No
# 2                      Arizona  United States                    No
# 3  Georgia - Northern District  United States                    No
# 4  Louisiana - Middle District  United States                    No
#
#                                       CASE_NAME        CASE_ID DOCKET_NO  \
# 0                     USA v. 1st Union Transfer  4:03-cr-00024         8
# 1                     USA v. 3D Poultry Loading  2:04-cr-20061         7
# 2  USA v. Danny's Management Services LLC et al  2:13-cr-01143       510
# 3                         USA v. 41 Market Inc.  4:06-cr-00023        11
# 4                              USA v. 45000 Inc  3:04-cr-00180        17
#
#          DATE JUDGMENT_DATE   PLEA_DATE TICKER US_PUBLIC_CO  \
# 0  2003-06-17    2003-06-17  2003-02-28    NaN           No
# 1  2005-01-25    2005-01-25  2004-09-30    NaN           No
# 2  2014-11-21    2014-11-21  2014-11-20    NaN           No
# 3  2006-07-05    2006-07-05  2006-03-16    NaN           No
# 4  2005-06-03    2005-06-03  2004-11-22    NaN           No
#
#    ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  COMMUNITY_SERVICE_OR_OTHER     FINE  \
# 0                                    NaN                         NaN      0.0
# 1                                    NaN                         NaN  24000.0
# 2                                    0.0                         0.0     50.0
# 3                                    NaN                         NaN  14640.0
# 4                                    NaN                         NaN  25000.0
#
#    FORFEITURE_DISGORGEMENT  PROBATION_LENGTH  RESTITUTION  TOTAL_PAYMENT  \
# 0                 272734.0              12.0          NaN         272734
# 1                      NaN              36.0          NaN          24000
# 2                      0.0               0.0          0.0             50
# 3                      NaN              36.0          NaN          14640
# 4                      NaN               0.0       2500.0          27500
#
#   ACCEPTS_RESPONSIBILITY AGREEMENT_REQUIRED_NEW_POSITIONS  \
# 0                    NaN                              NaN
# 1                    NaN                              NaN
# 2                    NaN                              NaN
# 3                    NaN                              NaN
# 4                    NaN                              NaN
#
#   AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS CITATION_AND_DESCRIPTION  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
# 2                                            NaN                      NaN
# 3                                            NaN                      NaN
# 4                                            NaN                      NaN
#
#   CIVIL_JUDGMENT_OR_SETTLEMENT COMPLIANCE_PROGRAM_DESCRIPTION  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#   COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT COMPLIANCE_REQUIRED_BY_REGULATORS  \
# 0                                      NaN                               NaN
# 1                                      NaN                               NaN
# 2                                      NaN                               NaN
# 3                                      NaN                               NaN
# 4                                      NaN                               NaN
#
#   CRIME_DESC DESCRIPTION_OF_PAYMENTS  \
# 0        NaN                     NaN
# 1        NaN                     NaN
# 2        NaN                     NaN
# 3        NaN                     NaN
# 4        NaN                     NaN
#
#   DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   DOJ_CAN_UNILATERALLY_TERMINATE FINE_CALCULATION_INCLUDED FINE_DESCRIPTION  \
# 0                            NaN                       NaN              NaN
# 1                            NaN                       NaN              NaN
# 2                            NaN                       NaN              NaN
# 3                            NaN                       NaN              NaN
# 4                            NaN                       NaN              NaN
#
#   INDEP_MONITOR_REQUIRED MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE  \
# 0                    NaN                                        NaN
# 1                    NaN                                        NaN
# 2                    NaN                                        NaN
# 3                    NaN                                        NaN
# 4                    NaN                                        NaN
#
#   OTHER_AGREEMENT OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2             NaN                                         NaN
# 3             NaN                                         NaN
# 4             NaN                                         NaN
#
#   OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED PARALLEL_CIVIL_SUIT  \
# 0                                             NaN                 NaN
# 1                                             NaN                 NaN
# 2                                             NaN                 NaN
# 3                                             NaN                 NaN
# 4                                             NaN                 NaN
#
#   PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR PRE_AGREEMENT_COMPLIANCE  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
# 2                                            NaN                      NaN
# 3                                            NaN                      NaN
# 4                                            NaN                      NaN
#
#   PRE_AGREEMENT_COMPLIANCE_DESCRIPTION PRIVACY_WAIVER  \
# 0                                  NaN            NaN
# 1                                  NaN            NaN
# 2                                  NaN            NaN
# 3                                  NaN            NaN
# 4                                  NaN            NaN
#
#    REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  REGULATORY_FINE REG_AGENCY  \
# 0                                             NaN              NaN        NaN
# 1                                             NaN              NaN        NaN
# 2                                             NaN              NaN        NaN
# 3                                             NaN              NaN        NaN
# 4                                             NaN              NaN        NaN
#
#   STATEMENT_OF_FACTS  TOTAL_REGULATORY UNRELATED_TERMS  AGMT_YEAR SOURCE NOTES
# 0                NaN               NaN             NaN     2003.0  PACER   NaN
# 1                NaN               NaN             NaN     2005.0  PACER   NaN
# 2                NaN               NaN             NaN     2014.0  PACER   NaN
# 3                NaN               NaN             NaN     2006.0  PACER   NaN
# 4                NaN               NaN             NaN     2005.0  PACER   NaN

# %% [markdown]
# ## How do you see the number of rows pandas will display? Then, set it to display 100 rows at a time.
#
# What does "the number rows pandas will display" actually mean?

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.set_option('display.height', 100)
pd.set_option('display.max_rows', 100)
df.head(10)
# Out:
# height has been deprecated.
#    REC_ID                                 COMPANY DISPOSITION_TYPE  \
# 0     138  1st Union Transfer and Telegraph, Inc.             plea
# 1     139                3D Poultry Loading, Inc.             plea
# 2    2529                         3rd & Bell, LLC             plea
# 3     822                          41 Market Inc.             plea
# 4     140                            45,000, Inc.             plea
# 5     823                         4628 Group Inc.             plea
# 6     824                           70 North, LLC             plea
# 7     825                       806 Trading Corp.             plea
# 8    2530                 83rd & Union Hills, LLC             plea
# 9    2531                        84th & Bell, LLC             plea
#
#                          PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM  \
# 0                          Money Laundering                NaN
# 1                               Immigration                NaN
# 2                               Immigration                NaN
# 3  Controlled substances / Drugs / Meth Act                NaN
# 4                             Environmental                NaN
# 5                             Environmental                NaN
# 6                             Environmental                NaN
# 7                                     Other                NaN
# 8                               Immigration                NaN
# 9                               Immigration                NaN
#
#                            USAO        COUNTRY FINANCIAL_INSTITUTION  \
# 0   Virginia - Eastern District  United States                   Yes
# 1   Arkansas - Western District  United States                    No
# 2                       Arizona  United States                    No
# 3   Georgia - Northern District  United States                    No
# 4   Louisiana - Middle District  United States                    No
# 5  New York - Northern District  United States                    No
# 6                        Alaska  United States                    No
# 7                    New Jersey  United States                    No
# 8                       Arizona  United States                    No
# 9                       Arizona  United States                    No
#
#                                       CASE_NAME        CASE_ID DOCKET_NO  \
# 0                     USA v. 1st Union Transfer  4:03-cr-00024         8
# 1                     USA v. 3D Poultry Loading  2:04-cr-20061         7
# 2  USA v. Danny's Management Services LLC et al  2:13-cr-01143       510
# 3                         USA v. 41 Market Inc.  4:06-cr-00023        11
# 4                              USA v. 45000 Inc  3:04-cr-00180        17
# 5                        USA v. 4628 Group Inc.  5:00-cr-00441         8
# 6                           USA v. 70 North LLC  4:13-po-00001       NaN
# 7                USA v. 806 TRADING CORPORATION  2:11-cr-00579         8
# 8  USA v. Danny's Management Services LLC et al  2:13-cr-01143       512
# 9  USA v. Danny's Management Services LLC et al  2:13-cr-01143       509
#
#          DATE JUDGMENT_DATE   PLEA_DATE TICKER US_PUBLIC_CO  \
# 0  2003-06-17    2003-06-17  2003-02-28    NaN           No
# 1  2005-01-25    2005-01-25  2004-09-30    NaN           No
# 2  2014-11-21    2014-11-21  2014-11-20    NaN           No
# 3  2006-07-05    2006-07-05  2006-03-16    NaN           No
# 4  2005-06-03    2005-06-03  2004-11-22    NaN           No
# 5  2001-07-31    2001-07-31  2000-09-20    NaN           No
# 6  2013-03-05    2013-03-05         NaN    NaN           No
# 7  2012-03-05    2012-03-05  2011-09-06    NaN           No
# 8  2014-11-24    2014-11-21  2014-11-20    NaN           No
# 9  2014-11-24    2014-11-21  2014-11-20    NaN           No
#
#    ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  COMMUNITY_SERVICE_OR_OTHER  \
# 0                                    NaN                         NaN
# 1                                    NaN                         NaN
# 2                                    0.0                         0.0
# 3                                    NaN                         NaN
# 4                                    NaN                         NaN
# 5                                    0.0                         NaN
# 6                                   35.0                         0.0
# 7                                    0.0                         0.0
# 8                                    0.0                         0.0
# 9                                    0.0                         0.0
#
#        FINE  FORFEITURE_DISGORGEMENT  PROBATION_LENGTH  RESTITUTION  \
# 0       0.0                 272734.0              12.0          NaN
# 1   24000.0                      NaN              36.0          NaN
# 2      50.0                      0.0               0.0          0.0
# 3   14640.0                      NaN              36.0          NaN
# 4   25000.0                      NaN               0.0       2500.0
# 5  500000.0                      0.0              24.0          0.0
# 6    2000.0                      0.0               0.0          0.0
# 7   42000.0                      0.0               0.0          0.0
# 8      50.0                      0.0               0.0          0.0
# 9      50.0                      0.0               0.0          0.0
#
#    TOTAL_PAYMENT ACCEPTS_RESPONSIBILITY AGREEMENT_REQUIRED_NEW_POSITIONS  \
# 0         272734                    NaN                              NaN
# 1          24000                    NaN                              NaN
# 2             50                    NaN                              NaN
# 3          14640                    NaN                              NaN
# 4          27500                    NaN                              NaN
# 5         500000                    NaN                              NaN
# 6           2000                    NaN                              NaN
# 7          42000                    NaN                              NaN
# 8             50                    NaN                              NaN
# 9             50                    NaN                              NaN
#
#   AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS CITATION_AND_DESCRIPTION  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
# 2                                            NaN                      NaN
# 3                                            NaN                      NaN
# 4                                            NaN                      NaN
# 5                                            NaN                      NaN
# 6                                            NaN                      NaN
# 7                                            NaN                      NaN
# 8                                            NaN                      NaN
# 9                                            NaN                      NaN
#
#   CIVIL_JUDGMENT_OR_SETTLEMENT COMPLIANCE_PROGRAM_DESCRIPTION  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
# 5                          NaN                            NaN
# 6                          NaN                            NaN
# 7                          NaN                            NaN
# 8                          NaN                            NaN
# 9                          NaN                            NaN
#
#   COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT COMPLIANCE_REQUIRED_BY_REGULATORS  \
# 0                                      NaN                               NaN
# 1                                      NaN                               NaN
# 2                                      NaN                               NaN
# 3                                      NaN                               NaN
# 4                                      NaN                               NaN
# 5                                      NaN                               NaN
# 6                                      NaN                               NaN
# 7                                      NaN                               NaN
# 8                                      NaN                               NaN
# 9                                      NaN                               NaN
#
#   CRIME_DESC DESCRIPTION_OF_PAYMENTS  \
# 0        NaN                     NaN
# 1        NaN                     NaN
# 2        NaN                     NaN
# 3        NaN                     NaN
# 4        NaN                     NaN
# 5        NaN                     NaN
# 6        NaN                     NaN
# 7        NaN                     NaN
# 8        NaN                     NaN
# 9        NaN                     NaN
#
#   DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#   DOJ_CAN_UNILATERALLY_TERMINATE FINE_CALCULATION_INCLUDED FINE_DESCRIPTION  \
# 0                            NaN                       NaN              NaN
# 1                            NaN                       NaN              NaN
# 2                            NaN                       NaN              NaN
# 3                            NaN                       NaN              NaN
# 4                            NaN                       NaN              NaN
# 5                            NaN                       NaN              NaN
# 6                            NaN                       NaN              NaN
# 7                            NaN                       NaN              NaN
# 8                            NaN                       NaN              NaN
# 9                            NaN                       NaN              NaN
#
#   INDEP_MONITOR_REQUIRED MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE  \
# 0                    NaN                                        NaN
# 1                    NaN                                        NaN
# 2                    NaN                                        NaN
# 3                    NaN                                        NaN
# 4                    NaN                                        NaN
# 5                    NaN                                        NaN
# 6                    NaN                                        NaN
# 7                    NaN                                        NaN
# 8                    NaN                                        NaN
# 9                    NaN                                        NaN
#
#   OTHER_AGREEMENT OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2             NaN                                         NaN
# 3             NaN                                         NaN
# 4             NaN                                         NaN
# 5             NaN                                         NaN
# 6             NaN                                         NaN
# 7             NaN                                         NaN
# 8             NaN                                         NaN
# 9             NaN                                         NaN
#
#   OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED PARALLEL_CIVIL_SUIT  \
# 0                                             NaN                 NaN
# 1                                             NaN                 NaN
# 2                                             NaN                 NaN
# 3                                             NaN                 NaN
# 4                                             NaN                 NaN
# 5                                             NaN                 NaN
# 6                                             NaN                 NaN
# 7                                             NaN                 NaN
# 8                                             NaN                 NaN
# 9                                             NaN                 NaN
#
#   PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR PRE_AGREEMENT_COMPLIANCE  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
# 2                                            NaN                      NaN
# 3                                            NaN                      NaN
# 4                                            NaN                      NaN
# 5                                            NaN                      NaN
# 6                                            NaN                      NaN
# 7                                            NaN                      NaN
# 8                                            NaN                      NaN
# 9                                            NaN                      NaN
#
#   PRE_AGREEMENT_COMPLIANCE_DESCRIPTION PRIVACY_WAIVER  \
# 0                                  NaN            NaN
# 1                                  NaN            NaN
# 2                                  NaN            NaN
# 3                                  NaN            NaN
# 4                                  NaN            NaN
# 5                                  NaN            NaN
# 6                                  NaN            NaN
# 7                                  NaN            NaN
# 8                                  NaN            NaN
# 9                                  NaN            NaN
#
#    REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  REGULATORY_FINE REG_AGENCY  \
# 0                                             NaN              NaN        NaN
# 1                                             NaN              NaN        NaN
# 2                                             NaN              NaN        NaN
# 3                                             NaN              NaN        NaN
# 4                                             NaN              NaN        NaN
# 5                                             NaN              NaN        NaN
# 6                                             NaN              NaN        NaN
# 7                                             NaN              NaN        NaN
# 8                                             NaN              NaN        NaN
# 9                                             NaN              NaN        NaN
#
#   STATEMENT_OF_FACTS  TOTAL_REGULATORY UNRELATED_TERMS  AGMT_YEAR SOURCE NOTES
# 0                NaN               NaN             NaN     2003.0  PACER   NaN
# 1                NaN               NaN             NaN     2005.0  PACER   NaN
# 2                NaN               NaN             NaN     2014.0  PACER   NaN
# 3                NaN               NaN             NaN     2006.0  PACER   NaN
# 4                NaN               NaN             NaN     2005.0  PACER   NaN
# 5                NaN               NaN             NaN     2001.0  PACER   NaN
# 6                NaN               NaN             NaN     2013.0  PACER   NaN
# 7                NaN               NaN             NaN     2012.0  PACER   NaN
# 8                NaN               NaN             NaN     2014.0  PACER   NaN
# 9                NaN               NaN             NaN     2014.0  PACER   NaN

# %% [markdown]
# ## Describe the TOTAL_PAYMENT column to me numerically - maxes, mins, averages.
#
# Do this in **one line.**

# %%
df['TOTAL_PAYMENT'].describe()
# Out:
# count    3.038000e+03
# mean     2.284273e+07
# std      1.556977e+08
# min      0.000000e+00
# 25%      2.189200e+04
# 50%      2.000000e+05
# 75%      2.100000e+06
# max      4.486800e+09
# Name: TOTAL_PAYMENT, dtype: float64

# %% [markdown]
# ### Oh that's ugly ugly ugly. Set pandas to format floats with 2 decimal points, we probably don't need to be more specific than that. Oh, and tell it to use a `,` in the thousands position!
#
# I'm just going to leave [this here](http://infohost.nmt.edu/~shipman/doc/python27/web/new-str-format.html) for reference. You should definitely come up and ask on the board, though.

# %%
pd.set_option('display.float_format', '{:,.2f}'.format)
df.TOTAL_PAYMENT.describe()
# Out:
# count           3,038.00
# mean       22,842,732.11
# std       155,697,740.02
# min                 0.00
# 25%            21,892.00
# 50%           200,000.00
# 75%         2,100,000.00
# max     4,486,800,000.00
# Name: TOTAL_PAYMENT, dtype: float64

# %% [markdown]
# ## Look at the fine and the forfeiture disgorgement for the first two rows. Pretty nice!

# %%
df.head(2)
# Out:
#    REC_ID                                 COMPANY DISPOSITION_TYPE  \
# 0     138  1st Union Transfer and Telegraph, Inc.             plea
# 1     139                3D Poultry Loading, Inc.             plea
#
#   PRIMARY_CRIME_CODE SWISS_BANK_PROGRAM                         USAO  \
# 0   Money Laundering                NaN  Virginia - Eastern District
# 1        Immigration                NaN  Arkansas - Western District
#
#          COUNTRY FINANCIAL_INSTITUTION                  CASE_NAME  \
# 0  United States                   Yes  USA v. 1st Union Transfer
# 1  United States                    No  USA v. 3D Poultry Loading
#
#          CASE_ID DOCKET_NO        DATE JUDGMENT_DATE   PLEA_DATE TICKER  \
# 0  4:03-cr-00024         8  2003-06-17    2003-06-17  2003-02-28    NaN
# 1  2:04-cr-20061         7  2005-01-25    2005-01-25  2004-09-30    NaN
#
#   US_PUBLIC_CO  ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  \
# 0           No                                    nan
# 1           No                                    nan
#
#    COMMUNITY_SERVICE_OR_OTHER      FINE  FORFEITURE_DISGORGEMENT  \
# 0                         nan      0.00               272,734.00
# 1                         nan 24,000.00                      nan
#
#    PROBATION_LENGTH  RESTITUTION  TOTAL_PAYMENT ACCEPTS_RESPONSIBILITY  \
# 0             12.00          nan         272734                    NaN
# 1             36.00          nan          24000                    NaN
#
#   AGREEMENT_REQUIRED_NEW_POSITIONS  \
# 0                              NaN
# 1                              NaN
#
#   AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS CITATION_AND_DESCRIPTION  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
#
#   CIVIL_JUDGMENT_OR_SETTLEMENT COMPLIANCE_PROGRAM_DESCRIPTION  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
#
#   COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT COMPLIANCE_REQUIRED_BY_REGULATORS  \
# 0                                      NaN                               NaN
# 1                                      NaN                               NaN
#
#   CRIME_DESC DESCRIPTION_OF_PAYMENTS  \
# 0        NaN                     NaN
# 1        NaN                     NaN
#
#   DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY  \
# 0                                                NaN
# 1                                                NaN
#
#   DOJ_CAN_UNILATERALLY_TERMINATE FINE_CALCULATION_INCLUDED FINE_DESCRIPTION  \
# 0                            NaN                       NaN              NaN
# 1                            NaN                       NaN              NaN
#
#   INDEP_MONITOR_REQUIRED MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE  \
# 0                    NaN                                        NaN
# 1                    NaN                                        NaN
#
#   OTHER_AGREEMENT OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
#
#   OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED PARALLEL_CIVIL_SUIT  \
# 0                                             NaN                 NaN
# 1                                             NaN                 NaN
#
#   PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR PRE_AGREEMENT_COMPLIANCE  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
#
#   PRE_AGREEMENT_COMPLIANCE_DESCRIPTION PRIVACY_WAIVER  \
# 0                                  NaN            NaN
# 1                                  NaN            NaN
#
#    REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  REGULATORY_FINE REG_AGENCY  \
# 0                                             nan              nan        NaN
# 1                                             nan              nan        NaN
#
#   STATEMENT_OF_FACTS  TOTAL_REGULATORY UNRELATED_TERMS  AGMT_YEAR SOURCE NOTES
# 0                NaN               nan             NaN   2,003.00  PACER   NaN
# 1                NaN               nan             NaN   2,005.00  PACER   NaN

# %% [markdown]
# # A little summarizing

# %% [markdown]
# ## How many of cases actually went to trial? How did most of these cases arrive at a decision?

# %%
df.DISPOSITION_TYPE.value_counts()
# Out:
# plea               2565
# NP                  266
# DP                  201
# declination           2
# dismissal             2
# trial convicton       2
# Name: DISPOSITION_TYPE, dtype: int64

# %%
# df.DISPOSITION_TYPE.notnull()
# df.DISPOSITION_TYPE.isnull()
# df[df.DISPOSITION_TYPE.notnull()]

# %% [markdown]
# ### Graph the previous answer, with the longest bar on top

# %%
# %matplotlib inline
df.DISPOSITION_TYPE.value_counts().sort_values(ascending = True).plot(kind='barh')

# %% [markdown]
# ## What's the distribution of total payments look like?

# %%
df.TOTAL_PAYMENT.hist()

# df.TOTAL_PAYMENT.hist(bins=[.......])

# %% [markdown]
# ## Sort by total payments, descending

# %%
df.TOTAL_PAYMENT.sort_values(ascending = False).head()
# Out:
# 307     4486800000
# 309     4000000000
# 2913    2800000000
# 1000    2003000000
# 753     1803488986
# Name: TOTAL_PAYMENT, dtype: int64

# %% [markdown]
# # Column selection
#
# We wanted to view all of those rows, but honestly that's a little silly. **We can't actually see the data we want!** Let's just select the ones we care about.
#
# ## Create a new dataframe that only includes the company name, disposition type, total payment, and date.

# %%
new_df = df[['COMPANY', 'DISPOSITION_TYPE', 'TOTAL_PAYMENT', 'DATE']].copy()
new_df.head()


# new = old[['A', 'C', 'D']].copy()
# Out:
#                                   COMPANY DISPOSITION_TYPE  TOTAL_PAYMENT  \
# 0  1st Union Transfer and Telegraph, Inc.             plea         272734
# 1                3D Poultry Loading, Inc.             plea          24000
# 2                         3rd & Bell, LLC             plea             50
# 3                          41 Market Inc.             plea          14640
# 4                            45,000, Inc.             plea          27500
#
#          DATE
# 0  2003-06-17
# 1  2005-01-25
# 2  2014-11-21
# 3  2006-07-05
# 4  2005-06-03

# %% [markdown]
# ## Confirm it has 3038 rows and 5 columns

# %%
new_df.shape
# Out:
# (3038, 4)

# %% [markdown]
# ## Using this subset, extract the year into a separate column called `year`
#
# Your machine will complain. **Let's talk about that error.**

# %%
YEAR = new_df['DATE'].str.extract('(\d\d\d\d)')
YEAR
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.
# 0       2003
# 1       2005
# 2       2014
# 3       2006
# 4       2005
# 5       2001
# 6       2013
# 7       2012
# 8       2014
# 9       2014
# 10      2001
# 11      2014
# 12      2003
# 13       NaN
# 14      2012
# 15      2013
# 16      2011
# 17      2004
# 18      2005
# 19      2009
# 20      2016
# 21      2012
# 22      2005
# 23      2008
# 24      2010
# 25      2010
# 26      2001
# 27      2004
# 28      2004
# 29      2012
# 30      2012
# 31      2013
# 32      2006
# 33      2010
# 34      2007
# 35      2015
# 36      2006
# 37      2000
# 38      2013
# 39      2000
# 40      2010
# 41      2005
# 42      2016
# 43      2011
# 44      2008
# 45      2009
# 46      2013
# 47      2006
# 48      2004
# 49      2004
#         ...
# 2988    2006
# 2989    2006
# 2990    2005
# 2991    2013
# 2992    2003
# 2993    2003
# 2994    2006
# 2995    2017
# 2996    2017
# 2997    2014
# 2998    2007
# 2999    2005
# 3000    2008
# 3001    2010
# 3002    2007
# 3003    2003
# 3004    2011
# 3005    2010
# 3006    2002
# 3007    2013
# 3008    2008
# 3009    2015
# 3010    2011
# 3011    2015
# 3012    2013
# 3013    2013
# 3014    2001
# 3015    2007
# 3016    2012
# 3017    2011
# 3018    2002
# 3019    2015
# 3020    2007
# 3021    2008
# 3022    2007
# 3023    2013
# 3024    2014
# 3025    2006
# 3026    2014
# 3027    2014
# 3028    2008
# 3029    2015
# 3030    2013
# 3031    2000
# 3032    2005
# 3033    2007
# 3034    2015
# 3035    2016
# 3036    2008
# 3037    2014
# Name: DATE, Length: 3038, dtype: object

# %%
new_df['YEAR'] = YEAR
new_df.head()
# Out:
#                                   COMPANY DISPOSITION_TYPE  TOTAL_PAYMENT  \
# 0  1st Union Transfer and Telegraph, Inc.             plea         272734
# 1                3D Poultry Loading, Inc.             plea          24000
# 2                         3rd & Bell, LLC             plea             50
# 3                          41 Market Inc.             plea          14640
# 4                            45,000, Inc.             plea          27500
#
#          DATE  YEAR
# 0  2003-06-17  2003
# 1  2005-01-25  2005
# 2  2014-11-21  2014
# 3  2006-07-05  2006
# 4  2005-06-03  2005

# %% [markdown]
# ## Make the 'year' column an integer.
#
# Or at least *try*, then turn it into a float. Why did one work but the other didn't?

# %%
new_df['YEAR'].astype(float).head()
# Out:
# 0   2,003.00
# 1   2,005.00
# 2   2,014.00
# 3   2,006.00
# 4   2,005.00
# Name: YEAR, dtype: float64

# %% [markdown]
# ## Make a histogram of cases over the years

# %%
# save it back into the column
new_df['YEAR'] = new_df['YEAR'].astype(float)

# %%
new_df['YEAR'].hist()

# %% [markdown]
# ## What was the total amount paid across all cases each year?

# %%
# new_df[["YEAR", "TOTAL_PAYMENT"]].groupby("YEAR").sum()

new_df.groupby('YEAR')["TOTAL_PAYMENT"].sum().head()
# Out:
# YEAR
# 1,992.00    0
# 1,993.00    0
# 1,994.00    0
# 1,996.00    0
# 1,998.00    0
# Name: TOTAL_PAYMENT, dtype: int64

# %% [markdown]
# ## Graph it!

# %%
# new_df.plot(kind="scatter", x = "YEAR", y="TOTAL_PAYMENT")

new_df.groupby('YEAR')["TOTAL_PAYMENT"].sum().plot(kind='bar')

# %% [markdown]
# # Cleaning up a column
#
# Take a look at **AGREEMENT_REQUIRED_NEW_POSITIONS** in your **ORIGINAL DATAFRAME**. How many times does it have a value in it?
#
# - Tip: There are a few ways to do this. Maybe you want to ask for an easy one!

# %%
df['AGREEMENT_REQUIRED_NEW_POSITIONS'].value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                           2777
# No                                                                                                                                                                                                             163
# Yes; Assignment one or more senior officers to compliance, with reporting obligations                                                                                                                           46
# Yes; Chief Compliance Officer                                                                                                                                                                                    6
# Yes; Compliance Officer                                                                                                                                                                                          6
# Yes; Compliance officer                                                                                                                                                                                          3
# Yes; Assigning one or more senior corporate officials to oversee compliance                                                                                                                                      2
# Yes; Appointe one employee as responsible for monitoring compliance                                                                                                                                              2
# Yes                                                                                                                                                                                                              2
# Yes; Assignment of one or more senior corporate officials to compliance, with authority to report to Audit Committee                                                                                             1
# Yes; Expanded compliance department, compliance officer, established Research Committee, Compliance Officer and Vide President and Corporate Compliance Officer with set responsibilities                        1
# Yes; Corporate Compliance Consultant                                                                                                                                                                             1
# Yes; Independent Chief Compliance Officer                                                                                                                                                                        1
# Yes; Two new independent directors to Board, establish Compliance Committee, Disclosure Committee, hire five new internal auditors, new Chief Compliance Officer, reorganize Finance Department                  1
# Yes; Executive Ethics Officer                                                                                                                                                                                    1
# Yes; Assigning "one or more senior corporate officials" to compliance oversight, reporting directly to Audit Committee                                                                                           1
# Yes; Assign responsibility to one or more senior officers to compliance, with reporting obligations                                                                                                              1
# Yes; Creation FTOC committee                                                                                                                                                                                     1
# Yes; Internal Audit Director, compliance committee                                                                                                                                                               1
# Yes; More safety and health department employees; larger training department                                                                                                                                     1
# Yes; New corporate governance committees                                                                                                                                                                         1
# Yes; Designated senior company officer as overseer of corporate compliance reporting                                                                                                                             1
# Yes; Compliance Officer, create Audit Committee, Nomination Committee, Compensation Commitee                                                                                                                     1
# Yes; Full time Compliance Officer                                                                                                                                                                                1
# Yes; Appoinment of executive Chairperson of Board of Directors, Compliance Committee                                                                                                                             1
# Yes; Designate CEO as Compliance officer                                                                                                                                                                         1
# Yes; Compliance Officer, reporting to President, CEO, Board Committees                                                                                                                                           1
# Yes; Appoint Chief Compliance Officer as member of Board, create Office of the Chief Compliance Officer                                                                                                          1
# Yes; Independent compliance and ethics committee of the board of directors                                                                                                                                       1
# Yes; Hired fulltime Director, Export Compliance, and independent Export Compliance Committee, Office of Firearms Control, replaced all executive leadership, full-time Director of Regulatory & Compliance       1
# Yes; Non-executive Chairman of Board, and additional non-executive Board member                                                                                                                                  1
# Yes; Compliance officer, two independent and outside directors including one to serve on audit committee consulting with DOJ on personnell decisions related to compliance program                               1
# Yes; Create Compliance Office, headed by Chief Compliance Officer                                                                                                                                                1
# Yes; Executive manager of compliance                                                                                                                                                                             1
# Yes; compliance officer                                                                                                                                                                                          1
# Yes; Retaining full time Chief Compliance Officer; assignment one or more senior officers to compliance, with reporting obligations                                                                              1
# Yes; Create new Ethics and Compliance Officer, full-time auditor posittion, new liaison position                                                                                                                 1
# Yes; New Compliance Office and Compliance Officer                                                                                                                                                                1
# Yes; Assignment one or more senior officers to compliance, with reporting obligations.                                                                                                                           1
# Yes; Executive Manager of Compliance                                                                                                                                                                             1
# Name: AGREEMENT_REQUIRED_NEW_POSITIONS, dtype: int64

# %% [markdown]
# ### What are the top 5 responses for `AGREEMENT_REQUIRED_NEW_POSITIONS`?

# %%
df['AGREEMENT_REQUIRED_NEW_POSITIONS'].value_counts(dropna=False).head(5)
# Out:
# NaN                                                                                      2777
# No                                                                                        163
# Yes; Assignment one or more senior officers to compliance, with reporting obligations      46
# Yes; Chief Compliance Officer                                                               6
# Yes; Compliance Officer                                                                     6
# Name: AGREEMENT_REQUIRED_NEW_POSITIONS, dtype: int64

# %% [markdown]
# ## That looks messy.
#
# ### HOLD ON, time to learn something
#
# **There are a few ways to do the next question**, but a couple popular methods will have pandas yell at you. You might want to try this new thing called `loc`! **It is used to update a column in a row based on a condition.**
#
# ```
# df.loc[df.country == 'Angola', "continent"] = "Africa"
# ```
#
# This updates the `continent` column to be `Africa` for every row where `df.country == 'Angola'`. You CANNOT do the following, which is probably what you've wanted to do:
#
# ```
# df[df.country == 'Angola']['continent'] = 'Africa'
# ```
#
# And now you know.
#
# ## Start to this up by creating a new column called `required_new_position`.
#
# This column should be `True` if a new position was required, `False` if a new position was not required, and `NaN` if it's unknown.
#
# - Tip: You should use `.str.contains`
# - Tip: Do you know how to say "at the start of a line" using regex?
# - Tip: We've talked about how to avoid `cannot index with vector containing NA / NaN values` but if you get it feel free to write it on the board

# %%
# df.loc[df.country == 'Angola', "continent"] = "Africa"
# This updates the continent column to be Africa for every row where df.country == 'Angola

df['REQUIRED_NEW_POSITIONS'] = df.AGREEMENT_REQUIRED_NEW_POSITIONS.str.contains('^Yes', na=False)
df.REQUIRED_NEW_POSITIONS.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: REQUIRED_NEW_POSITIONS, dtype: bool

# %% [markdown]
# ### Confirm that your new column has 163 `True` values and 98 `False` values

# %%
df['REQUIRED_NEW_POSITIONS'].value_counts()
# Out:
# False    2940
# True       98
# Name: REQUIRED_NEW_POSITIONS, dtype: int64

# %% [markdown]
# ## Extract the position name into a new column called `new_position`

# %%
#df['NEW_POSITIONS'] = df[df['REQUIRED_NEW_POSITIONS'] == True]['AGREEMENT_REQUIRED_NEW_POSITIONS'].str.extract('^Yes;(.*)')
df['NEW_POSITIONS'] = df['AGREEMENT_REQUIRED_NEW_POSITIONS'].str.extract('^Yes;(.*)')

df['NEW_POSITIONS'].dropna().head(10)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# 23      Assigning "one or more senior corporate offic...
# 44      Assigning one or more senior corporate offici...
# 45      Assigning one or more senior corporate offici...
# 63      Hired fulltime Director, Export Compliance, a...
# 74      More safety and health department employees; ...
# 98      Appoinment of executive Chairperson of Board ...
# 115     Assignment of one or more senior corporate of...
# 124     Assignment one or more senior officers to com...
# 147     Assignment one or more senior officers to com...
# 222     Assignment one or more senior officers to com...
# Name: NEW_POSITIONS, dtype: object

# %%
df[df['REQUIRED_NEW_POSITIONS'] == True]['NEW_POSITIONS'].head()
# Out:
# 23     Assigning "one or more senior corporate offic...
# 30                                                  NaN
# 44     Assigning one or more senior corporate offici...
# 45     Assigning one or more senior corporate offici...
# 63     Hired fulltime Director, Export Compliance, a...
# Name: NEW_POSITIONS, dtype: object

# %% [markdown]
# ## Make sure you extracted correctly
#
# The line below should show at least SIX rows. If it doesn't show any rows, something went wrong!
#
# - Tip: A `.value_counts()` might look okay, even though something is a little off.

# %%
df[df.NEW_POSITIONS == " Compliance Officer"]['NEW_POSITIONS']
# Out:
# 441      Compliance Officer
# 664      Compliance Officer
# 1063     Compliance Officer
# 1657     Compliance Officer
# 1661     Compliance Officer
# 3005     Compliance Officer
# Name: NEW_POSITIONS, dtype: object

# %% [markdown]
# ## Find all cases that required a compliance officer
#
# That one above only gives us six. We want more! **Find at least 23 cases that required the creation of a compliance officer.**
#
# - Tip: Regular expressions might be your friend here
# - Tip: If you get an error about **new_position** not being found, change your code from when you created the column from `df.new_position = ...` to `df['new_position'] = ...`

# %%
df[df['NEW_POSITIONS'].str.contains("Compliance Officer", na=False)]['NEW_POSITIONS'].value_counts()
# Out:
#  Compliance Officer                                                                                                                                                                            6
#  Chief Compliance Officer                                                                                                                                                                      6
#  Create new Ethics and Compliance Officer, full-time auditor posittion, new liaison position                                                                                                   1
#  Retaining full time Chief Compliance Officer; assignment one or more senior officers to compliance, with reporting obligations                                                                1
#  Compliance Officer, create Audit Committee, Nomination Committee, Compensation Commitee                                                                                                       1
#  Independent Chief Compliance Officer                                                                                                                                                          1
#  Compliance Officer, reporting to President, CEO, Board Committees                                                                                                                             1
#  New Compliance Office and Compliance Officer                                                                                                                                                  1
#  Create Compliance Office, headed by Chief Compliance Officer                                                                                                                                  1
#  Full time Compliance Officer                                                                                                                                                                  1
#  Two new independent directors to Board, establish Compliance Committee, Disclosure Committee, hire five new internal auditors, new Chief Compliance Officer, reorganize Finance Department    1
#  Appoint Chief Compliance Officer as member of Board, create Office of the Chief Compliance Officer                                                                                            1
#  Expanded compliance department, compliance officer, established Research Committee, Compliance Officer and Vide President and Corporate Compliance Officer with set responsibilities          1
# Name: NEW_POSITIONS, dtype: int64

# %% [markdown]
# ## View the cases that have a compliance officer again.
#
# This time you shouldn't have a `...` in the middle of your dataframe.

# %%
df[df['NEW_POSITIONS'].str.contains("Compliance Officer", na=False)].head()
# Out:
#      REC_ID                 COMPANY DISPOSITION_TYPE PRIMARY_CRIME_CODE  \
# 276     655  Atrium Companies, Inc.               NP        Immigration
# 362     754            Bashas, Inc.               NP               Food
# 415     580             Biomet Inc.               DP               FCPA
# 441     663              Boeing Co.               NP    Fraud - General
# 664     587    Columbia Farms, Inc.               DP        Immigration
#
#     SWISS_BANK_PROGRAM                                               USAO  \
# 276                 No                          Texas - Southern District
# 362                 No                                            Arizona
# 415                 No          USDOJ - Criminal Division - Fraud Section
# 441                 No  California - Central District,Virginia - Easte...
# 664                 No                                     South Carolina
#
#            COUNTRY FINANCIAL_INSTITUTION CASE_NAME CASE_ID DOCKET_NO  \
# 276  United States                    No       NaN     NaN       NaN
# 362  United States                    No       NaN     NaN       NaN
# 415  United States                    No       NaN     NaN       NaN
# 441  United States                    No       NaN     NaN       NaN
# 664  United States                    No       NaN     NaN       NaN
#
#            DATE JUDGMENT_DATE PLEA_DATE TICKER US_PUBLIC_CO  \
# 276  2012-01-01           NaN       NaN    NaN           No
# 362  2013-08-30           NaN       NaN    NaN           No
# 415  2012-03-26           NaN       NaN    NaN          Yes
# 441  2006-06-01           NaN       NaN    NaN          Yes
# 664  2009-11-03           NaN       NaN    NaN           No
#
#      ADDITIONAL_REGULATORY_FINE_OR_PAYMENT  COMMUNITY_SERVICE_OR_OTHER  \
# 276                           2,000,000.00                         nan
# 362                                    nan                         nan
# 415                                   0.00                         nan
# 441                                   0.00                         nan
# 664                           1,500,000.00                         nan
#
#              FINE  FORFEITURE_DISGORGEMENT  PROBATION_LENGTH  RESTITUTION  \
# 276          0.00                      nan               nan 2,000,000.00
# 362          0.00                      nan             24.00 1,472,487.00
# 415 17,800,000.00                      nan             36.00          nan
# 441 50,000,000.00                      nan             24.00          nan
# 664          0.00                      nan             24.00 1,500,000.00
#
#      TOTAL_PAYMENT ACCEPTS_RESPONSIBILITY  \
# 276        2000000                    NaN
# 362        1472487                    Yes
# 415       17800000                    Yes
# 441       50000000                    Yes
# 664        1500000                    Yes
#
#                       AGREEMENT_REQUIRED_NEW_POSITIONS  \
# 276                      Yes; Chief Compliance Officer
# 362                      Yes; Chief Compliance Officer
# 415  Yes; Expanded compliance department, complianc...
# 441                            Yes; Compliance Officer
# 664                            Yes; Compliance Officer
#
#     AGREEMENT_REQUIRED_OUTSIDE_AUDITORS_OR_EXPERTS  \
# 276                                            NaN
# 362                                             No
# 415                                             No
# 441                                             No
# 664                                             No
#
#                               CITATION_AND_DESCRIPTION  \
# 276  Yes (writ of attachment for $5 million and inj...
# 362                                                NaN
# 415                                                NaN
# 441  Yes (RICO - possession of competitor documents...
# 664                                                NaN
#
#                           CIVIL_JUDGMENT_OR_SETTLEMENT  \
# 276  Unknown (couldn't find any information except ...
# 362                                                NaN
# 415                                                NaN
# 441                                                NaN
# 664                                                NaN
#
#                         COMPLIANCE_PROGRAM_DESCRIPTION  \
# 276  Hire full time chief compliance officer and co...
# 362  Imposing discipline on involved employees; new...
# 415  Compliance department expanded, policy review ...
# 441  Training; discipline; prohibiting retaliation;...
# 664  Designation of compliance officer; ICE reporti...
#
#     COMPLIANCE_PROGRAM_REQUIRED_BY_AGREEMENT  \
# 276                                      Yes
# 362                                      Yes
# 415                                      Yes
# 441                                      Yes
# 664                                      Yes
#
#                      COMPLIANCE_REQUIRED_BY_REGULATORS  \
# 276                                                 No
# 362                                                 No
# 415         Yes; HHS-OIG Corporate Integrity Agreement
# 441  Yes; Interim Agreement with Air Force: maintai...
# 664                                                NaN
#
#                                             CRIME_DESC  \
# 276                                        Immigration
# 362    Food-related USDA violations (mislabeling meat)
# 415        Anti-Kickback Statute (payments to doctors)
# 441  Federal procurement fraud, conflict of interes...
# 664                      Immigration, false statements
#
#     DESCRIPTION_OF_PAYMENTS  \
# 276                     NaN
# 362                     NaN
# 415                     NaN
# 441                     NaN
# 664                     NaN
#
#     DOES_AGREEMENT_DISCUSS_REASONS_OR_RELEVENT_CONSIDERATIONS_FOR_LENIENCY  \
# 276                                                  .
# 362  Yes; cooperation, acknowledging responsibility...
# 415  Yes; remedial actions, cooperation, acceptance...
# 441  Yes; in exchange for good faith performance of...
# 664  Yes; acceptance of responsibility, compliance,...
#
#                         DOJ_CAN_UNILATERALLY_TERMINATE  \
# 276                                                NaN
# 362                                                Yes
# 415                                                Yes
# 441  No; But "conduct by a Boeing employee classifi...
# 664                                                Yes
#
#     FINE_CALCULATION_INCLUDED  \
# 276                       NaN
# 362                        No
# 415                        No
# 441                        No
# 664                        No
#
#                                       FINE_DESCRIPTION INDEP_MONITOR_REQUIRED  \
# 276  $2,000,000 to Department of Homeland Security ...                     No
# 362  $1.47 million went to Tuscon Community Food Ba...                     No
# 415  None; simultaneous settlement with DOJ Civil D...                    Yes
# 441  $50M penalty, $565M civil settlement; $1.9M to...                    Yes
# 664                                              $1.5M                     No
#
#             MUST_COMPORT_WITH_USSG_OR_AUDIT_COMPLIANCE       OTHER_AGREEMENT  \
# 276                                                NaN                   NaN
# 362                                                 No                   NaN
# 415                                                 No                   NaN
# 441       Yes; Periodic auditing of compliance program  Interim Admin. Agmt.
# 664  Yes; Use of e-Verify program, annual review of...                   NaN
#
#         OTHER_AGREEMENT_REQUIRED_GOVERNANCE_CHANGES  \
# 276                                             NaN
# 362                                              No
# 415  Yes; Detailed rules for Consulting Agreements)
# 441                                              No
# 664                                              No
#
#     OTHER_COMPLIANCE_OFFICER_OR_CONSULTANT_REQUIRED PARALLEL_CIVIL_SUIT  \
# 276                                              No                 Yes
# 362                                              No                 NaN
# 415                                              No                  No
# 441                                             Yes                 Yes
# 664                                              No                  No
#
#     PARALLEL_REGULATORY_ACTION_OR_LOCAL_PROSECUTOR PRE_AGREEMENT_COMPLIANCE  \
# 276                                            NaN                      Yes
# 362                                            NaN                      Yes
# 415        Yes; HHS-OIG ($26.9 million settlement)                      Yes
# 441                                            Yes                      Yes
# 664                                            NaN                      Yes
#
#                   PRE_AGREEMENT_COMPLIANCE_DESCRIPTION PRIVACY_WAIVER  \
# 276  Yes; Substantial remedial measures; revising i...            NaN
# 362  Yes; Thorough internal investigation and volun...             No
# 415                    Yes; Pre-agreement ethics codes             No
# 441  Yes; Changes to ethics and compliance program;...             No
# 664  Yes; Cites significant remedial actions taken ...             No
#
#      REGULATORY_DISGORGEMENT_RESTITUTION_FORFEITURE  REGULATORY_FINE  \
# 276                                             nan              nan
# 362                                             nan              nan
# 415                                             nan    26,900,000.00
# 441                                    1,900,000.00   595,000,000.00
# 664                                             nan              nan
#
#                                             REG_AGENCY STATEMENT_OF_FACTS  \
# 276  Dept. of Homeland Security - Immigration & Cus...                NaN
# 362                               Dept. of Agriculture                Yes
# 415  Dept. of Health & Human Services - Office of t...                 No
# 441  National Aeronautics and Space Administration ...                Yes
# 664  Dept. of Homeland Security;Dept. of Homeland S...                Yes
#
#      TOTAL_REGULATORY UNRELATED_TERMS  AGMT_YEAR        SOURCE  \
# 276              0.00             NaN   2,012.00  FOIA request
# 362               nan              No   2,013.00           NaN
# 415     26,900,000.00              No   2,012.00           NaN
# 441    596,900,000.00              No   2,006.00           NaN
# 664              0.00              No   2,009.00           NaN
#
#                                                  NOTES  \
# 276                                                NaN
# 362                                                NaN
# 415                                                NaN
# 441  Information regarding the Interim Agreement: h...
# 664                                                NaN
#
#      REQUIRED_NEW_POSITIONS                                      NEW_POSITIONS
# 276                    True                           Chief Compliance Officer
# 362                    True                           Chief Compliance Officer
# 415                    True   Expanded compliance department, compliance of...
# 441                    True                                 Compliance Officer
# 664                    True                                 Compliance Officer

# %% [markdown]
# ## What were the most popular crimes that required a compliance officer's appointment?

# %%
df.groupby('NEW_POSITIONS')["PRIMARY_CRIME_CODE"].value_counts().sort_values(ascending = False)
# Out:
# NEW_POSITIONS                                                                                                                                                                                           PRIMARY_CRIME_CODE
#  Assignment one or more senior officers to compliance, with reporting obligations                                                                                                                       FCPA                                     44
#  Chief Compliance Officer                                                                                                                                                                               Fraud - Health Care                       2
#  Appointe one employee as responsible for monitoring compliance                                                                                                                                         Fraud - General                           2
#  Assigning one or more senior corporate officials to oversee compliance                                                                                                                                 FCPA                                      2
#  Assignment one or more senior officers to compliance, with reporting obligations                                                                                                                       Kickbacks                                 2
#  Compliance Officer                                                                                                                                                                                     Immigration                               2
#                                                                                                                                                                                                         Fraud - General                           2
#  Chief Compliance Officer                                                                                                                                                                               Fraud - Tax                               1
#  Compliance Officer, reporting to President, CEO, Board Committees                                                                                                                                      Kickbacks                                 1
#  Compliance Officer, create Audit Committee, Nomination Committee, Compensation Commitee                                                                                                                Fraud - Securities                        1
#  Compliance Officer                                                                                                                                                                                     Kickbacks                                 1
#                                                                                                                                                                                                         Fraud - Tax                               1
#  Chief Compliance Officer                                                                                                                                                                               Immigration                               1
#  compliance officer                                                                                                                                                                                     Other                                     1
#  Chief Compliance Officer                                                                                                                                                                               Food                                      1
#                                                                                                                                                                                                         FCPA                                      1
#  Compliance officer                                                                                                                                                                                     Fraud - Tax                               1
#  Assignment one or more senior officers to compliance, with reporting obligations.                                                                                                                      FCPA                                      1
#  Assignment of one or more senior corporate officials to compliance, with authority to report to Audit Committee                                                                                        FCPA                                      1
#  Assigning "one or more senior corporate officials" to compliance oversight, reporting directly to Audit Committee                                                                                      FCPA                                      1
#  Assign responsibility to one or more senior officers to compliance, with reporting obligations                                                                                                         FCPA                                      1
#  Appoint Chief Compliance Officer as member of Board, create Office of the Chief Compliance Officer                                                                                                     Kickbacks                                 1
#  Compliance officer                                                                                                                                                                                     Fraud - General                           1
#                                                                                                                                                                                                         Immigration                               1
#  Two new independent directors to Board, establish Compliance Committee, Disclosure Committee, hire five new internal auditors, new Chief Compliance Officer, reorganize Finance Department             Fraud - Securities                        1
#  Full time Compliance Officer                                                                                                                                                                           Immigration                               1
#  Retaining full time Chief Compliance Officer; assignment one or more senior officers to compliance, with reporting obligations                                                                         FCPA                                      1
#  Non-executive Chairman of Board, and additional non-executive Board member                                                                                                                             Fraud - Securities                        1
#  New corporate governance committees                                                                                                                                                                    Fraud - Tax                               1
#  New Compliance Office and Compliance Officer                                                                                                                                                           Kickbacks                                 1
#  More safety and health department employees; larger training department                                                                                                                                OSHA / Workplace Safety / Mine Safety     1
#  Internal Audit Director, compliance committee                                                                                                                                                          Fraud - General                           1
#  Independent compliance and ethics committee of the board of directors                                                                                                                                  Bank Secrecy Act                          1
#  Independent Chief Compliance Officer                                                                                                                                                                   Environmental                             1
#  Hired fulltime Director, Export Compliance, and independent Export Compliance Committee, Office of Firearms Control, replaced all executive leadership, full-time Director of Regulatory & Compliance  Import / Export                           1
#  Expanded compliance department, compliance officer, established Research Committee, Compliance Officer and Vide President and Corporate Compliance Officer with set responsibilities                   FCPA                                      1
#  Compliance officer, two independent and outside directors including one to serve on audit committee consulting with DOJ on personnell decisions related to compliance program                          Fraud - Accounting                        1
#  Executive manager of compliance                                                                                                                                                                        Import / Export                           1
#  Executive Manager of Compliance                                                                                                                                                                        Import / Export                           1
#  Executive Ethics Officer                                                                                                                                                                               Other                                     1
#  Designated senior company officer as overseer of corporate compliance reporting                                                                                                                        FCPA                                      1
#  Designate CEO as Compliance officer                                                                                                                                                                    Fraud - General                           1
#  Creation FTOC committee                                                                                                                                                                                Fraud - Accounting                        1
#  Create new Ethics and Compliance Officer, full-time auditor posittion, new liaison position                                                                                                            Fraud - General                           1
#  Create Compliance Office, headed by Chief Compliance Officer                                                                                                                                           Kickbacks                                 1
#  Corporate Compliance Consultant                                                                                                                                                                        Kickbacks                                 1
#  Appoinment of executive Chairperson of Board of Directors, Compliance Committee                                                                                                                        FCPA                                      1
# Name: PRIMARY_CRIME_CODE, dtype: int64

# %% [markdown]
# # Make a comparison between two groups in the full dataset
#
# For example, "cases before 2003 were likely to be about this, but after 2003 they became about something else."

# %%
df.groupby('PRIMARY_CRIME_CODE')['PROBATION_LENGTH'].value_counts().head(10)
# Out:
# PRIMARY_CRIME_CODE                   PROBATION_LENGTH
# Act to Prevent Pollution from Ships  36.00                51
#                                      60.00                15
#                                      48.00                13
#                                      24.00                 7
#                                      12.00                 4
#                                      0.00                  3
#                                      30.00                 1
# Antitrust                            0.00                120
#                                      60.00                31
#                                      24.00                23
# Name: PROBATION_LENGTH, dtype: int64

# %%
df.groupby('PRIMARY_CRIME_CODE')['PROBATION_LENGTH'].value_counts().plot(kind="bar")

# Ughhh...graph is too ugly!
