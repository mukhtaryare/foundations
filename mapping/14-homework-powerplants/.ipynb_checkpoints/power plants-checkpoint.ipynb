# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
# %matplotlib inline

# %% [markdown]
# * **1:** How many power plants are in each state?
# * **2:** Which power plants are in New York?
# * **3:** Which state has the most hydroelectric power plants?
# * **4:** Which state produces the most energy from coal?
# * **5:** Map states with nuclear power plants in red, and states without in grey. Do the same thing for solar.
# * **6:** Make a map of carbon dioxide emissions by state, with low emissions being light orange and high emissions being * orange.
# * **7:** Make a map of total energy produced by each state, with little being a light color and high emissions being a brighter/darker color.
# * **8:** Make a map of total wind (or solar or coal) energy produced by each state, with little being a light color and high emissions being a brighter/darker color.
# * **9:** Make a map of average air quality of each states, with high quality being light red and low quality being dark red
# * **10:** Make a map of worst air quality measured in each state, with high quality being light red and low quality being dark red
# * **11:** Map of average PM2.5 measurement by county
# * **12:** Make a map with color coded power plants, and a 100 mile circle about major American cities.
# * **13:** Which states have the most renewable plants, as a % of total plants? (include hydro, wind, solar)

# %%
us_states = gpd.read_file('cb_2016_us_state_500k/cb_2016_us_state_500k.shp')
us_states.head()
# Out:
#       AFFGEOID          ALAND        AWATER GEOID LSAD        NAME STATEFP  \
# 0  0400000US01   131173688951    4593686489    01   00     Alabama      01
# 1  0400000US02  1477946266785  245390495931    02   00      Alaska      02
# 2  0400000US04   294198560125    1027346486    04   00     Arizona      04
# 3  0400000US05   134771517596    2960191698    05   00    Arkansas      05
# 4  0400000US06   403501101370   20466718403    06   00  California      06
#
#     STATENS STUSPS                                           geometry
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 1  01785533     AK  (POLYGON ((-134.737262 58.261354, -134.73441 5...
# 2  01779777     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3  00068085     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...
# 4  01779778     CA  (POLYGON ((-118.604415 33.478552, -118.598783 ...

# %%
df = pd.read_csv('powerplants.csv')
points = df.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
powerplants = gpd.GeoDataFrame(df, geometry=points)
powerplants.crs = {'init': 'epsg:4326'}
powerplants.head()
# Out:
#    Plant_Code          Plant_Name        Utility_Na  Utility_ID  \
# 0           2        Bankhead Dam  Alabama Power Co         195
# 1           3               Barry  Alabama Power Co         195
# 2           4  Walter Bouldin Dam  Alabama Power Co         195
# 3           7             Gadsden  Alabama Power Co         195
# 4           8              Gorgas  Alabama Power Co         195
#
#          sector_nam       City      County    Zip            Street_Add  \
# 0  Electric Utility  Northport  Tuscaloosa  35476    19001 Lock 17 Road
# 1  Electric Utility      Bucks      Mobile  36512      North Highway 43
# 2  Electric Utility   Wetumpka      Elmore  36092  750 Bouldin Dam Road
# 3  Electric Utility    Gadsden      Etowah  35903     1000 Goodyear Ave
# 4  Electric Utility    Parrish      Walker  35580       460 Gorgas Road
#
#       PrimSource                  ...                   Wind_MW  Geo_MW  \
# 0  hydroelectric                  ...                       0.0     NaN
# 1           coal                  ...                       0.0     NaN
# 2  hydroelectric                  ...                       0.0     NaN
# 3    natural gas                  ...                       0.0     NaN
# 4           coal                  ...                       0.0     NaN
#
#    Other_MW                               source_des  \
# 0       NaN                    Hydroelectric = 56 MW
# 1       NaN  Coal = 1088.5 MW, Natural Gas = 1072 MW
# 2       NaN                 Hydroelectric = 225.9 MW
# 3       NaN                     Natural Gas = 130 MW
# 4       NaN                           Coal = 1034 MW
#
#                                            tech_desc  \
# 0                         Conventional Hydroelectric
# 1  Conventional Steam Coal; Natural Gas Fired Com...
# 2                         Conventional Hydroelectric
# 3                          Natural Gas Steam Turbine
# 4                            Conventional Steam Coal
#
#                           Source  Period   Latitude  Longitude  \
# 0  EIA-860, EIA-860M and EIA-923  201607  33.458665 -87.356823
# 1  EIA-860, EIA-860M and EIA-923  201607  31.006900 -88.010300
# 2  EIA-860, EIA-860M and EIA-923  201607  32.583889 -86.283056
# 3  EIA-860, EIA-860M and EIA-923  201607  34.012800 -85.970800
# 4  EIA-860, EIA-860M and EIA-923  201607  33.644344 -87.196486
#
#                                geometry
# 0  POINT (-87.35682299999999 33.458665)
# 1              POINT (-88.0103 31.0069)
# 2          POINT (-86.283056 32.583889)
# 3              POINT (-85.9708 34.0128)
# 4  POINT (-87.19648599999999 33.644344)
#
# [5 rows x 29 columns]

# %%
us_states.crs
# Out:
# {'init': 'epsg:4269'}

# %%
powerplants.crs
# Out:
# {'init': 'epsg:4326'}

# %%
us_states.to_crs(powerplants.crs, inplace=True)

# %%
us_states.crs
# Out:
# {'init': 'epsg:4326'}

# %%
# In order to spatially join the data, they need to be in the same crs. 
# Set the CRS of the us_states map to be the same as the powerplants. Use .head() to make sure the switch worked.
#us_states = us_states.to_crs(epsg=5071)
us_states.head()
# Out:
#       AFFGEOID          ALAND        AWATER GEOID LSAD        NAME STATEFP  \
# 0  0400000US01   131173688951    4593686489    01   00     Alabama      01
# 1  0400000US02  1477946266785  245390495931    02   00      Alaska      02
# 2  0400000US04   294198560125    1027346486    04   00     Arizona      04
# 3  0400000US05   134771517596    2960191698    05   00    Arkansas      05
# 4  0400000US06   403501101370   20466718403    06   00  California      06
#
#     STATENS STUSPS                                           geometry
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 1  01785533     AK  (POLYGON ((-134.737262 58.261354, -134.73441 5...
# 2  01779777     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3  00068085     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...
# 4  01779778     CA  (POLYGON ((-118.604415 33.478552, -118.598783 ...

# %%
us_states.plot()

# %%
powerplants.plot()

# %%
# gpd.sjoin - joins the two datasets together
# we are keeping the geometry of all the powerplants...order is important.
# inner means if powerplants doesn't have a state, get rid off it. - gives only powerplants attached to state
# within - looking for powerplants that are within a state
# left means keep all the powerplants even if they don't have a matching state.

powerplants_with_states = gpd.sjoin(powerplants, us_states, how='inner', op='within')
pd.set_option('display.max_columns', 100)
powerplants_with_states.head(2)
# Out:
#    Plant_Code    Plant_Name        Utility_Na  Utility_ID        sector_nam  \
# 0           2  Bankhead Dam  Alabama Power Co         195  Electric Utility
# 1           3         Barry  Alabama Power Co         195  Electric Utility
#
#         City      County    Zip          Street_Add     PrimSource  Total_MW  \
# 0  Northport  Tuscaloosa  35476  19001 Lock 17 Road  hydroelectric      56.0
# 1      Bucks      Mobile  36512    North Highway 43           coal    2160.5
#
#    Coal_MW   NG_MW  Crude_MW  Bio_MW  Hydro_MW  HydroPS_MW  Nuclear_MW  \
# 0      0.0     0.0       0.0     NaN      56.0         0.0         0.0
# 1   1088.5  1072.0       0.0     NaN       0.0         0.0         0.0
#
#    Solar_MW  Wind_MW  Geo_MW  Other_MW  \
# 0       0.0      0.0     NaN       NaN
# 1       0.0      0.0     NaN       NaN
#
#                                 source_des  \
# 0                    Hydroelectric = 56 MW
# 1  Coal = 1088.5 MW, Natural Gas = 1072 MW
#
#                                            tech_desc  \
# 0                         Conventional Hydroelectric
# 1  Conventional Steam Coal; Natural Gas Fired Com...
#
#                           Source  Period   Latitude  Longitude  \
# 0  EIA-860, EIA-860M and EIA-923  201607  33.458665 -87.356823
# 1  EIA-860, EIA-860M and EIA-923  201607  31.006900 -88.010300
#
#                                geometry  index_right     AFFGEOID  \
# 0  POINT (-87.35682299999999 33.458665)            0  0400000US01
# 1              POINT (-88.0103 31.0069)            0  0400000US01
#
#           ALAND      AWATER GEOID LSAD     NAME STATEFP   STATENS STUSPS
# 0  131173688951  4593686489    01   00  Alabama      01  01779775     AL
# 1  131173688951  4593686489    01   00  Alabama      01  01779775     AL

# %% [markdown]
# ### 1: How many power plants are in each state?

# %%
powerplants_with_states.NAME.value_counts()
# Out:
# California              1222
# North Carolina           461
# Texas                    396
# New York                 372
# Minnesota                274
# Massachusetts            254
# Iowa                     222
# Michigan                 219
# New Jersey               207
# Pennsylvania             207
# Illinois                 200
# Wisconsin                174
# Colorado                 153
# Ohio                     148
# Oregon                   145
# Florida                  144
# Georgia                  139
# Washington               138
# Alaska                   138
# Idaho                    136
# Indiana                  133
# Virginia                 131
# Kansas                   129
# Missouri                 117
# Arizona                  113
# Nebraska                  98
# Maine                     97
# South Carolina            95
# Oklahoma                  94
# New Mexico                92
# Utah                      89
# Connecticut               88
# Louisiana                 84
# Maryland                  76
# Vermont                   75
# Nevada                    74
# Alabama                   72
# New Hampshire             66
# Wyoming                   62
# Tennessee                 61
# Arkansas                  55
# Hawaii                    50
# Montana                   50
# North Dakota              50
# Kentucky                  46
# Mississippi               40
# West Virginia             35
# South Dakota              33
# Delaware                  25
# Rhode Island              19
# District of Columbia       2
# Name: NAME, dtype: int64

# %% [markdown]
# ### 2: Which power plants are in New York?

# %%
powerplants_with_states[powerplants_with_states.NAME == 'New York']
# Out:
#       Plant_Code                           Plant_Name  \
# 49            88                              Ashokan
# 363          579            Central Hudson High Falls
# 387          625                  Upper Mechanicville
# 469          808                    Jarvis (Hinckley)
# 1169        2480        Danskammer Generating Station
# 1170        2481                            Dashville
# 1171        2483                            Neversink
# 1172        2485                          South Cairo
# 1173        2486                             Sturgeon
# 1174        2487                       West Coxsackie
# 1175        2490       Arthur Kill Generating Station
# 1176        2493                           East River
# 1191                       Main Road      petroleum      10.0      0.0
# 1192                11 Bahama Street      petroleum      49.7      0.0
# 1193                   59 Goddeau Rd  hydroelectric       5.5      0.0
# 1194                  590 Plant Road           coal     107.5    107.5
# ...                              ...            ...       ...      ...
# 6617               812 S Suffolk Ave          solar       1.0      0.0
# 6618              Long Island Avenue          solar       2.5      0.0
# 6619   100 Veterans Memorial Highway          solar       2.0      0.0
# 6620   725 Veterans Memorial Highway          solar       1.0      0.0
# 6621            200-201 Center Drive          solar       1.5      0.0
# 6622             400 Carleton Avenue          solar       4.0      0.0
# 6643     1335 Avenue of the Americas    natural gas       1.8      0.0
# 6685             27 County Route 25A  hydroelectric       4.0      0.0
# 6973  NY State Rte 25 and Fresh Pond          solar       5.0      0.0
# 6974        Middle Rd and  Tucker Ln          solar       1.3      0.0
# 6975  NY State Rte 25 and Peconic Av          solar       9.5      0.0
# 7088                  470 Myrtle Ave    natural gas       3.5      0.0
# 7105                 800 Snyder Road          solar       1.8      0.0
# 7198                 6742 Pound Road          solar       1.2      0.0
# 7204                309 NY Routh 11b          solar       2.0      0.0
# 7320       131 Millbrook School Road          solar       1.4      0.0
# 7338                  286 Knapp Road        biomass       4.0      0.0
# 7430                   166 S RTE 303          solar       2.0      0.0
# 7484                   4170 Route 31          solar       1.0      0.0
# 7514                3425 Sutton Road          solar       2.0      0.0
# 7571            5362 Railroad Street          solar       1.6      0.0
# 7587                 122 Denton Road          solar       2.0      0.0
# 7590                170 North Street          solar       2.0      0.0
# 7597          3651 Middle Country Rd          solar       3.9      0.0
# 7598                   4720 Baker St          solar       2.0      0.0
# 7599                1 Willard Avenue          solar       2.6      0.0
# 7600                 6415 Sutliff Rd          solar       1.9      0.0
# 7601                 6575 Sutliff Rd          solar       1.9      0.0
# 7604             253-A Bridge Street          solar       1.7      0.0
# 7605             253-B Bridge Street          solar       1.0      0.0
#
#        NG_MW  Crude_MW  Bio_MW  Hydro_MW  HydroPS_MW  Nuclear_MW  Solar_MW  \
# 49       0.0       0.0     NaN       4.6         0.0         0.0       0.0
# 363      0.0       0.0     NaN       3.2         0.0         0.0       0.0
# 387      0.0       0.0     NaN      18.4         0.0         0.0       0.0
# 469      0.0       0.0     NaN       9.0         0.0         0.0       0.0
# 1169   478.7       5.0     NaN       0.0         0.0         0.0       0.0
# 1170     0.0       0.0     NaN       4.8         0.0         0.0       0.0
# 1171     0.0       0.0     NaN      22.0         0.0         0.0       0.0
# 1172     0.0      21.3     NaN       0.0         0.0         0.0       0.0
# 1173     0.0       0.0     NaN      14.4         0.0         0.0       0.0
# 1174     0.0      21.3     NaN       0.0         0.0         0.0       0.0
# 1175   858.0       0.0     NaN       0.0         0.0         0.0       0.0
# 1176   629.3       0.0     NaN       0.0         0.0         0.0       0.0
# 1177   280.1     269.2     NaN       0.0         0.0         0.0       0.0
# 1178     0.0      41.7     NaN       0.0         0.0         0.0       0.0
# 1179     0.0       0.0     NaN       0.0         0.0      1020.0       0.0
# 1180   283.4       0.0     NaN       0.0         0.0         0.0       0.0
#                              Source  Period   Latitude  Longitude  \
# 49    EIA-860, EIA-860M and EIA-923  201607  41.949000 -74.206300
# 363   EIA-860, EIA-860M and EIA-923  201607  41.828814 -74.131877
# 387   EIA-860, EIA-860M and EIA-923  201607  42.912600 -73.680500
# 469   EIA-860, EIA-860M and EIA-923  201607  43.312100 -75.109000
# 1169  EIA-860, EIA-860M and EIA-923  201607  41.571247 -73.974981
# 1170  EIA-860, EIA-860M and EIA-923  201607  41.821700 -74.049700
# 1171  EIA-860, EIA-860M and EIA-923  201607  41.819400 -74.635800
# 1172  EIA-860, EIA-860M and EIA-923  201607  42.291275 -73.986452
# 1173  EIA-860, EIA-860M and EIA-923  201607  41.848191 -74.046678
# 1174  EIA-860, EIA-860M and EIA-923  201607  42.343500 -73.835300
# 1175  EIA-860, EIA-860M and EIA-923  201607  40.591564 -74.200035
# 1176  EIA-860, EIA-860M and EIA-923  201607  40.728100 -73.974200
# 1177  EIA-860, EIA-860M and EIA-923  201607  40.663500 -74.005100
# 1178  EIA-860, EIA-860M and EIA-923  201607  40.705200 -73.980700
# 1179  EIA-860, EIA-860M and EIA-923  201607  41.270556 -73.952700
# 1180  EIA-860, EIA-860M and EIA-923  201607  40.648611 -74.020833
# 1181  EIA-860, EIA-860M and EIA-923  201607  40.759167 -73.946111
# 1182  EIA-860, EIA-860M and EIA-923  201607  40.771285 -73.991150
# 1183  EIA-860, EIA-860M and EIA-923  201607  40.768000 -73.951500
# 1184  EIA-860, EIA-860M and EIA-923  201607  40.616689 -73.647881
# 1185  EIA-860, EIA-860M and EIA-923  201607  40.961706 -72.210277
# 1186  EIA-860, EIA-860M and EIA-923  201607  40.827149 -73.647473
# 1187  EIA-860, EIA-860M and EIA-923  201607  40.923565 -73.342323
# 1188  EIA-860, EIA-860M and EIA-923  201607  40.949696 -73.078507
# 1189  EIA-860, EIA-860M and EIA-923  201607  40.961590 -72.864976
# 1190  EIA-860, EIA-860M and EIA-923  201607  40.899997 -72.381977
# 1191  EIA-860, EIA-860M and EIA-923  201607  41.105900 -72.376100
# 1192  EIA-860, EIA-860M and EIA-923  201607  40.695485 -73.348573
# 1193  EIA-860, EIA-860M and EIA-923  201607  44.695000 -73.621900
# 1194  EIA-860, EIA-860M and EIA-923  201607  42.678900 -76.948300
# ...                             ...     ...        ...        ...
# 6617  EIA-860, EIA-860M and EIA-923  201607  40.781389 -73.243889
# 6618  EIA-860, EIA-860M and EIA-923  201607  40.760833 -73.193889
# 6619  EIA-860, EIA-860M and EIA-923  201607  40.763056 -73.323611
# 6620  EIA-860, EIA-860M and EIA-923  201607  40.763056 -73.323611
# 6621  EIA-860, EIA-860M and EIA-923  201607  40.826111 -73.232222
# 6622  EIA-860, EIA-860M and EIA-923  201607  40.762465 -73.194441
# 6643  EIA-860, EIA-860M and EIA-923  201607  40.762500 -73.979167
# 6685  EIA-860, EIA-860M and EIA-923  201607  42.351389 -73.733889
# 6973  EIA-860, EIA-860M and EIA-923  201607  40.928056 -72.771111
# 6974  EIA-860, EIA-860M and EIA-923  201607  41.067500 -72.440278
powerplants_with_states[powerplants_with_states.PrimSource == 'hydroelectric'].NAME.value_counts()
# Out:
# California        245
# New York          159
# Washington         77
# Idaho              75
# Oregon             60
# Wisconsin          59
# Michigan           53
# Maine              52
# Colorado           43
# Vermont            42
# North Carolina     41
# New Hampshire      38
# South Carolina     31
# Utah               29
# Georgia            29
# Massachusetts      28
# Tennessee          27
# Virginia           23
# Alabama            23
# Alaska             23
# Montana            23
# Texas              22
# Minnesota          21
# Arkansas           19
# Wyoming            16
# Pennsylvania       16
# Connecticut        13
# West Virginia      12
# Nebraska           10
# Oklahoma           10
# Kentucky            9
# Illinois            8
# Hawaii              7
# Nevada              7
# Arizona             7
# Indiana             6
# Missouri            5
# Ohio                4
# South Dakota        4
# New Mexico          4
# Maryland            3
# Rhode Island        2
# Florida             2
# Iowa                2
# New Jersey          2
# Louisiana           1
# North Dakota        1
# Kansas              1
# Name: NAME, dtype: int64

# %% [markdown]
# ### 4: Which state produces the most energy from coal?

# %%
us_states.set_index('NAME', inplace=True)
us_states.head()
# Out:
#                AFFGEOID          ALAND        AWATER GEOID LSAD STATEFP  \
# NAME
# Alabama     0400000US01   131173688951    4593686489    01   00      01
# Alaska      0400000US02  1477946266785  245390495931    02   00      02
# Arizona     0400000US04   294198560125    1027346486    04   00      04
# Arkansas    0400000US05   134771517596    2960191698    05   00      05
# California  0400000US06   403501101370   20466718403    06   00      06
#
#              STATENS STUSPS                                           geometry
# NAME
# Alabama     01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# Alaska      01785533     AK  (POLYGON ((-134.737262 58.261354, -134.73441 5...
# Arizona     01779777     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...
# Arkansas    00068085     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...
# California  01779778     CA  (POLYGON ((-118.604415 33.478552, -118.598783 ...

# %%
# us_states['Coal_MW'] = powerplants_with_states.NAME.sum()
# us_states.head()

# %%
powerplants_with_states.groupby('NAME')['Coal_MW'].sum().sort_values(ascending=False).head()
# Out:
# NAME
# Texas           23588.5
# Indiana         16111.4
# Ohio            15189.9
# Illinois        14644.6
# Pennsylvania    13313.4
# Name: Coal_MW, dtype: float64

# %%
us_states['Coal_MW'] =  powerplants_with_states.groupby('NAME')['Coal_MW'].sum()
us_states.head()
# Out:
#                AFFGEOID          ALAND        AWATER GEOID LSAD STATEFP  \
# NAME
# Alabama     0400000US01   131173688951    4593686489    01   00      01
# Alaska      0400000US02  1477946266785  245390495931    02   00      02
# Arizona     0400000US04   294198560125    1027346486    04   00      04
# Arkansas    0400000US05   134771517596    2960191698    05   00      05
# California  0400000US06   403501101370   20466718403    06   00      06
#
#              STATENS STUSPS  \
# NAME
# Alabama     01779775     AL
# Alaska      01785533     AK
# Arizona     01779777     AZ
# Arkansas    00068085     AR
# California  01779778     CA
#
#                                                      geometry  Coal_MW
# NAME
# Alabama     (POLYGON ((-88.053375 30.506987, -88.051087999...   7979.4
# Alaska      (POLYGON ((-134.737262 58.261354, -134.73441 5...    153.8
# Arizona     POLYGON ((-114.816294 32.508038, -114.814321 3...   5910.0
# Arkansas    POLYGON ((-94.6178329666013 36.4994141203285, ...   5122.4
# California  (POLYGON ((-118.604415 33.478552, -118.598783 ...     90.0

# %% [markdown]
# ### 5: Map states with nuclear power plants in red, and states without in grey. Do the same thing for solar.

# %%
states_with_nuclear = powerplants_with_states[(powerplants_with_states['PrimSource'] == 'nuclear')]
states_with_nuclear.head(2)
# Out:
#       Plant_Code       Plant_Name                  Utility_Na  Utility_ID  \
# 22            46     Browns Ferry  Tennessee Valley Authority       18642
# 1820        6001  Joseph M Farley            Alabama Power Co         195
#
#             sector_nam      City     County    Zip  \
# 22    Electric Utility   Decatur  Limestone  35609
# 1820  Electric Utility  Columbia    Houston  36319
#
#                        Street_Add PrimSource  Total_MW  Coal_MW  NG_MW  \
# 22           Shaw Rd. PO Box 2000    nuclear    3309.4      0.0    0.0
# 1820  7388 North State Highway 95    nuclear    1757.0      0.0    0.0
#
#       Crude_MW  Bio_MW  Hydro_MW  HydroPS_MW  Nuclear_MW  Solar_MW  Wind_MW  \
# 22         0.0     NaN       0.0         0.0      3309.4       0.0      0.0
# 1820       0.0     NaN       0.0         0.0      1757.0       0.0      0.0
#
#       Geo_MW  Other_MW           source_des tech_desc  \
# 22       NaN       NaN  Nuclear = 3309.4 MW   Nuclear
# 1820     NaN       NaN    Nuclear = 1757 MW   Nuclear
#
#                              Source  Period  Latitude  Longitude  \
# 22    EIA-860, EIA-860M and EIA-923  201607   34.7042   -87.1189
# 1820  EIA-860, EIA-860M and EIA-923  201607   31.2231   -85.1116
#
#                       geometry  index_right     AFFGEOID         ALAND  \
# 22    POINT (-87.1189 34.7042)            0  0400000US01  131173688951
# 1820  POINT (-85.1116 31.2231)            0  0400000US01  131173688951
#
#           AWATER GEOID LSAD     NAME STATEFP   STATENS STUSPS
# 22    4593686489    01   00  Alabama      01  01779775     AL
# 1820  4593686489    01   00  Alabama      01  01779775     AL

# %%
states_without_nuclear = powerplants_with_states[(powerplants_with_states['PrimSource'] != 'nuclear')]
states_without_nuclear.head(2)
# Out:
#    Plant_Code    Plant_Name        Utility_Na  Utility_ID        sector_nam  \
# 0           2  Bankhead Dam  Alabama Power Co         195  Electric Utility
# 1           3         Barry  Alabama Power Co         195  Electric Utility
#
#         City      County    Zip          Street_Add     PrimSource  Total_MW  \
# 0  Northport  Tuscaloosa  35476  19001 Lock 17 Road  hydroelectric      56.0
# 1      Bucks      Mobile  36512    North Highway 43           coal    2160.5
#
#    Coal_MW   NG_MW  Crude_MW  Bio_MW  Hydro_MW  HydroPS_MW  Nuclear_MW  \
# 0      0.0     0.0       0.0     NaN      56.0         0.0         0.0
# 1   1088.5  1072.0       0.0     NaN       0.0         0.0         0.0
#
#    Solar_MW  Wind_MW  Geo_MW  Other_MW  \
# 0       0.0      0.0     NaN       NaN
# 1       0.0      0.0     NaN       NaN
#
#                                 source_des  \
# 0                    Hydroelectric = 56 MW
# 1  Coal = 1088.5 MW, Natural Gas = 1072 MW
#
#                                            tech_desc  \
# 0                         Conventional Hydroelectric
# 1  Conventional Steam Coal; Natural Gas Fired Com...
#
#                           Source  Period   Latitude  Longitude  \
# 0  EIA-860, EIA-860M and EIA-923  201607  33.458665 -87.356823
# 1  EIA-860, EIA-860M and EIA-923  201607  31.006900 -88.010300
#
#                                geometry  index_right     AFFGEOID  \
# 0  POINT (-87.35682299999999 33.458665)            0  0400000US01
# 1              POINT (-88.0103 31.0069)            0  0400000US01
#
#           ALAND      AWATER GEOID LSAD     NAME STATEFP   STATENS STUSPS
# 0  131173688951  4593686489    01   00  Alabama      01  01779775     AL
# 1  131173688951  4593686489    01   00  Alabama      01  01779775     AL

# %%
ax = us_states.plot(figsize=(15, 10), color='gray')
states_with_nuclear.plot(color='red', ax=ax)
ax.set_xlim([-130,-60])
ax.set_ylim([25,50])
# ax.axis('off')

# states_without_nuclear = powerplants_with_states[(powerplants_with_states['PrimSource'] != 'nuclear')]
# Out:
# (25, 50)

# %%
states_with_solar = powerplants_with_states[(powerplants_with_states['PrimSource'] == 'solar')]
states_with_solar.head(2)
# Out:
#       Plant_Code                         Plant_Name        Utility_Na  \
# 5285       57197  Blue Wing Solar Energy Generation    TX Solar I LLC
# 5679       57699          Webberville Solar Project  FRV AE Solar LLC
#
#       Utility_ID   sector_nam         City  County    Zip  \
# 5285       56565  IPP Non-CHP  San Antonio   Bexar  78223
# 5679       57021  IPP Non-CHP        Manor  Travis  78653
#
#                  Street_Add PrimSource  Total_MW  Coal_MW  NG_MW  Crude_MW  \
# 5285  10810 S Blue Wind Rd.      solar      13.5      0.0    0.0       0.0
# 5679           18580 FM 969      solar      30.0      0.0    0.0       0.0
#
#       Bio_MW  Hydro_MW  HydroPS_MW  Nuclear_MW  Solar_MW  Wind_MW  Geo_MW  \
# 5285     NaN       0.0         0.0         0.0      13.5      0.0     NaN
# 5679     NaN       0.0         0.0         0.0      30.0      0.0     NaN
#
#       Other_MW       source_des           tech_desc  \
# 5285       NaN  Solar = 13.5 MW  Solar Photovoltaic
# 5679       NaN    Solar = 30 MW  Solar Photovoltaic
#
#                              Source  Period   Latitude  Longitude  \
# 5285  EIA-860, EIA-860M and EIA-923  201607  29.304177 -98.400339
# 5679  EIA-860, EIA-860M and EIA-923  201607  30.238492 -97.508812
#
#                                   geometry  index_right     AFFGEOID  \
# 5285          POINT (-98.400339 29.304177)           49  0400000US48
# 5679  POINT (-97.50881200000001 30.238492)           49  0400000US48
#
#              ALAND       AWATER GEOID LSAD   NAME STATEFP   STATENS STUSPS
# 5285  676633459408  19025991684    48   00  Texas      48  01779801     TX
# 5679  676633459408  19025991684    48   00  Texas      48  01779801     TX

# %%
states_without_solar = powerplants_with_states[(powerplants_with_states['PrimSource'] != 'solar')]
states_without_solar.head(2)
# Out:
#    Plant_Code    Plant_Name        Utility_Na  Utility_ID        sector_nam  \
# 0           2  Bankhead Dam  Alabama Power Co         195  Electric Utility
# 1           3         Barry  Alabama Power Co         195  Electric Utility
#
#         City      County    Zip          Street_Add     PrimSource  Total_MW  \
# 0  Northport  Tuscaloosa  35476  19001 Lock 17 Road  hydroelectric      56.0
# 1      Bucks      Mobile  36512    North Highway 43           coal    2160.5
#
#    Coal_MW   NG_MW  Crude_MW  Bio_MW  Hydro_MW  HydroPS_MW  Nuclear_MW  \
# 0      0.0     0.0       0.0     NaN      56.0         0.0         0.0
# 1   1088.5  1072.0       0.0     NaN       0.0         0.0         0.0
#
#    Solar_MW  Wind_MW  Geo_MW  Other_MW  \
# 0       0.0      0.0     NaN       NaN
# 1       0.0      0.0     NaN       NaN
#
#                                 source_des  \
# 0                    Hydroelectric = 56 MW
# 1  Coal = 1088.5 MW, Natural Gas = 1072 MW
#
#                                            tech_desc  \
# 0                         Conventional Hydroelectric
# 1  Conventional Steam Coal; Natural Gas Fired Com...
#
#                           Source  Period   Latitude  Longitude  \
# 0  EIA-860, EIA-860M and EIA-923  201607  33.458665 -87.356823
# 1  EIA-860, EIA-860M and EIA-923  201607  31.006900 -88.010300
#
#                                geometry  index_right     AFFGEOID  \
# 0  POINT (-87.35682299999999 33.458665)            0  0400000US01
# 1              POINT (-88.0103 31.0069)            0  0400000US01
#
#           ALAND      AWATER GEOID LSAD     NAME STATEFP   STATENS STUSPS
# 0  131173688951  4593686489    01   00  Alabama      01  01779775     AL
# 1  131173688951  4593686489    01   00  Alabama      01  01779775     AL

# %%
ax = us_states.plot(figsize=(15, 10), color='gray')
states_with_solar.plot(color='blue', ax=ax)
ax.set_xlim([-130,-60])
ax.set_ylim([25,50])
# ax.axis('off')
# Out:
# (25, 50)

# %% [markdown]
# ### 6: Make a map of carbon dioxide emissions by state, with low emissions being light orange and high emissions being * orange.

# %%
carbondioxide = pd.read_csv('Total Carbon Dioxide Emissions-StateRankings.csv')
carbondioxide.head()
# Out:
#    Rank State  Carbon_Dioxide _Emissions  \
# 0     1    TX                        642
# 1     2    CA                        358
# 2     3    PA                        245
# 3     4    IL                        234
# 4     5    OH                        232
#
#    Note: Rankings are based on the full source data values.
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
us_states.head()
# Out:
#                AFFGEOID          ALAND        AWATER GEOID LSAD STATEFP  \
# NAME
# Alabama     0400000US01   131173688951    4593686489    01   00      01
# Alaska      0400000US02  1477946266785  245390495931    02   00      02
# Arizona     0400000US04   294198560125    1027346486    04   00      04
# Arkansas    0400000US05   134771517596    2960191698    05   00      05
# California  0400000US06   403501101370   20466718403    06   00      06
#
#              STATENS STUSPS  \
# NAME
# Alabama     01779775     AL
# Alaska      01785533     AK
# Arizona     01779777     AZ
# Arkansas    00068085     AR
# California  01779778     CA
#
#                                                      geometry  Coal_MW
# NAME
# Alabama     (POLYGON ((-88.053375 30.506987, -88.051087999...   7979.4
# Alaska      (POLYGON ((-134.737262 58.261354, -134.73441 5...    153.8
# Arizona     POLYGON ((-114.816294 32.508038, -114.814321 3...   5910.0
# Arkansas    POLYGON ((-94.6178329666013 36.4994141203285, ...   5122.4
# California  (POLYGON ((-118.604415 33.478552, -118.598783 ...     90.0

# %%
# new_data = pd.merge(left, right, how='left'
# combine = powerplants_with_states.join(carbondioxide, on="STUSPS")
# combine.head()

new_data = us_states[['STUSPS', 'geometry']]
new_data.head()
# Out:
#            STUSPS                                           geometry
# NAME
# Alabama        AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# Alaska         AK  (POLYGON ((-134.737262 58.261354, -134.73441 5...
# Arizona        AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...
# Arkansas       AR  POLYGON ((-94.6178329666013 36.4994141203285, ...
# California     CA  (POLYGON ((-118.604415 33.478552, -118.598783 ...

# %%
combine = new_data.merge(carbondioxide, left_on="STUSPS", right_on="State")
combine.head()
# Out:
#   STUSPS                                           geometry  Rank State  \
# 0     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...    15    AL
# 1     AK  (POLYGON ((-134.737262 58.261354, -134.73441 5...    40    AK
# 2     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...    23    AZ
# 3     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...    29    AR
# 4     CA  (POLYGON ((-118.604415 33.478552, -118.598783 ...     2    CA
#
#    Carbon_Dioxide _Emissions  \
# 0                        123
# 1                         35
# 2                         93
# 3                         69
# 4                        358
#
#    Note: Rankings are based on the full source data values.
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
del combine['State']

# %%
del combine['Note: Rankings are based on the full source data values.']

# %%
combine.head()
# Out:
#   STUSPS                                           geometry  Rank  \
# 0     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...    15
# 1     AK  (POLYGON ((-134.737262 58.261354, -134.73441 5...    40
# 2     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...    23
# 3     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...    29
# 4     CA  (POLYGON ((-118.604415 33.478552, -118.598783 ...     2
#
#    Carbon_Dioxide _Emissions
# 0                        123
# 1                         35
# 2                         93
# 3                         69
# 4                        358

# %%
# 6: Make a map of carbon dioxide emissions by state, 
# with low emissions being light orange and high emissions being * orange.

ax =combine.plot(column='Carbon_Dioxide _Emissions', figsize=(15, 10), cmap='Oranges')

# ax = us_states.plot(figsize=(15, 10), color='gray')
# combine.plot(color='blue', ax=ax)
ax.set_xlim([-130,-60])
ax.set_ylim([25,50])
# ax.axis('off')
# Out:
# (25, 50)

# %%
us_states.reset_index(inplace=True)

# %% [markdown]
# ### 7: Make a map of total energy produced by each state, with little being a light color and high emissions being a brighter/darker color.

# %% [markdown]
# ### 9: Make a map of average air quality of each states, with high quality being light red and low quality being dark red

# %%
df = pd.read_csv('pm25_annual_fixed.csv', usecols = ['Latitude', 'Longitude', 'Datum', 'Arithmetic Mean', '1st Max Value', 'State Name', 'County Name', 'City Name'])
points = df.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
air_quality = gpd.GeoDataFrame(df, geometry=points)
air_quality.crs = {'init': 'epsg:4326'}
air_quality.head()
# Out:
#     Latitude  Longitude  Datum  Arithmetic Mean  1st Max Value State Name  \
# 0  30.497478 -87.880258  NAD83         6.535714           15.4    Alabama
# 1  33.284928 -85.803608  NAD83         8.851852           19.0    Alabama
# 2  34.762619 -87.638097  NAD83         7.650000           17.8    Alabama
# 3  34.288567 -85.969858  NAD83         8.083333           14.8    Alabama
# 4  33.991494 -85.992647  NAD83         9.073333           17.5    Alabama
#
#   County Name      City Name                              geometry
# 0     Baldwin       Fairhope          POINT (-87.880258 30.497478)
# 1        Clay        Ashland          POINT (-85.803608 33.284928)
# 2     Colbert  Muscle Shoals          POINT (-87.638097 34.762619)
# 3      DeKalb     Crossville          POINT (-85.969858 34.288567)
# 4      Etowah        Gadsden  POINT (-85.99264699999998 33.991494)

# %%
us_states.head()
# Out:
#    level_0  index        NAME     AFFGEOID          ALAND        AWATER GEOID  \
# 0        0      0     Alabama  0400000US01   131173688951    4593686489    01
# 1        1      1      Alaska  0400000US02  1477946266785  245390495931    02
# 2        2      2     Arizona  0400000US04   294198560125    1027346486    04
# 3        3      3    Arkansas  0400000US05   134771517596    2960191698    05
# 4        4      4  California  0400000US06   403501101370   20466718403    06
#
#   LSAD STATEFP   STATENS STUSPS  \
# 0   00      01  01779775     AL
# 1   00      02  01785533     AK
# 2   00      04  01779777     AZ
# 3   00      05  00068085     AR
# 4   00      06  01779778     CA
#
#                                             geometry  Coal_MW
# 0  (POLYGON ((-88.053375 30.506987, -88.051087999...   7979.4
# 1  (POLYGON ((-134.737262 58.261354, -134.73441 5...    153.8
# 2  POLYGON ((-114.816294 32.508038, -114.814321 3...   5910.0
# 3  POLYGON ((-94.6178329666013 36.4994141203285, ...   5122.4
# 4  (POLYGON ((-118.604415 33.478552, -118.598783 ...     90.0

# %%
states_air_quality = gpd.sjoin(us_states, air_quality, how='left', op='contains')
# pd.set_option('display.max_columns', 100)
states_air_quality.head(2)
# Out:
#    level_0  index     NAME     AFFGEOID         ALAND      AWATER GEOID LSAD  \
# 0        0      0  Alabama  0400000US01  131173688951  4593686489    01   00
# 0        0      0  Alabama  0400000US01  131173688951  4593686489    01   00
#
#   STATEFP   STATENS STUSPS                                           geometry  \
# 0      01  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 0      01  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
#
#    Coal_MW index_right   Latitude  Longitude  Datum  Arithmetic Mean  \
# 0   7979.4          12  30.770181 -88.087761  NAD83         7.635714
# 0   7979.4           0  30.497478 -87.880258  NAD83         6.535714
#
#    1st Max Value State Name County Name  City Name
# 0           17.7    Alabama      Mobile  Chickasaw
# 0           15.4    Alabama     Baldwin   Fairhope

# %%
ax = states_air_quality.plot(column='Arithmetic Mean', figsize=(15, 10), cmap='Reds')

# ax = us_states.plot(figsize=(15, 10), color='gray')
# combine.plot(color='blue', ax=ax)
ax.set_xlim([-130,-60])
ax.set_ylim([25,50])
# ax.axis('off')
# Out:
# (25, 50)

# %% [markdown]
# ### 10: Make a map of worst air quality measured in each state, with high quality being light red and low quality being dark red

# %%
ax = states_air_quality.plot(column='1st Max Value', figsize=(15, 10), cmap='Reds')

# ax = us_states.plot(figsize=(15, 10), color='gray')
# combine.plot(color='blue', ax=ax)
ax.set_xlim([-130,-60])
ax.set_ylim([25,50])
# ax.axis('off')
# Out:
# (25, 50)

# %%
### 11: Map of average PM2.5 measurement by county
